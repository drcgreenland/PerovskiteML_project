# %% [markdown]
# ### ChemBERT
# 1. Initial data cleaning and preprocessing of Perovskite database query.csv
# - Filtering for relevant columns - features and key performance metrics

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\c\OneDrive\Documents\PEROVSKITE PROJECT\PerovskiteML_project\Data\Perovsite database query.csv')

# relevant columns listed below, any with >85% missing values have been removed

columns_to_keep = [
    'Cell_stack_sequence', 'Cell_architecture',
    'Substrate_stack_sequence',
    'ETL_stack_sequence',
    'Perovskite_composition_a_ions', 'Perovskite_composition_a_ions_coefficients', 
    'Perovskite_composition_b_ions', 'Perovskite_composition_b_ions_coefficients',
    'Perovskite_composition_c_ions', 'Perovskite_composition_c_ions_coefficients', 
    'Perovskite_composition_short_form', 'Perovskite_composition_long_form', 'Perovskite_composition_leadfree', 'Perovskite_composition_inorganic',
    'Perovskite_additives_compounds', 'Perovskite_thickness', 'Perovskite_band_gap',
    'HTL_stack_sequence', 'HTL_additives_compounds',
    'Backcontact_stack_sequence',
    'Encapsulation', 'Encapsulation_stack_sequence', 'JV_default_PCE',
    'JV_default_Voc', 'JV_default_Jsc', 'JV_default_FF', 'JV_hysteresis_index', 'Stabilised_performance_measured', 'Stability_measured',
    'Stability_average_over_n_number_of_cells', 'Stability_light_source_type', 'Stability_light_intensity', 'Stability_atmosphere', 
    'Stability_time_total_exposure', 'Stability_PCE_end_of_experiment'
]

df = df[columns_to_keep]

df.columns = df.columns.str.strip()

ion_columns = ['Perovskite_composition_a_ions', 'Perovskite_composition_a_ions_coefficients', 
    'Perovskite_composition_b_ions', 'Perovskite_composition_b_ions_coefficients',
    'Perovskite_composition_c_ions', 'Perovskite_composition_c_ions_coefficients']

columns_to_check = ['Perovskite_composition_a_ions', 'Perovskite_composition_a_ions_coefficients', 
    'Perovskite_composition_b_ions', 'Perovskite_composition_b_ions_coefficients',
    'Perovskite_composition_c_ions', 'Perovskite_composition_c_ions_coefficients', 
    'Perovskite_composition_short_form', 'Perovskite_composition_long_form']

df = df.dropna(subset=columns_to_check)

# Filter for single-layered perovskites only (>98%)

df['Layer Type'] = df.apply(
    lambda row: 'Multi-layered Perovskite' if any('|' in str(row[col]) for col in ion_columns) else 'Single-layered Perovskite',
    axis=1
)
df = df[df['Layer Type'] == 'Single-layered Perovskite']

# Filter out any HTL-free devices

df = df[df['HTL_stack_sequence'] != 'none']

output_file_path = 'initial_cleaned_data.csv'

df.to_csv(output_file_path, index=False)
# Out:
# C:\Users\c\AppData\Local\Temp\ipykernel_23040\2391026991.py:3: DtypeWarning: Columns (10,22,29,31,32,35,36,40,44,45,46,48,51,54,65,84,89,90,93,98,99,100,105,108,115,118,122,123,125,130,134,138,142,143,144,146,149,152,163,166,167,171,172,173,175,178,181,192,194,225,271,272,273,277,304,315,321,325,330,331,335,336,342,348,369,371,373,374,376,380,384,387,403,405,407,409) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\c\OneDrive\Documents\PEROVSKITE PROJECT\PerovskiteML_project\Data\Perovsite database query.csv')

# %% [markdown]
# ### SMILES - Data Preprocessing
# Feature engineering/Preparing our data for the ChemBERTa model - creating SMILES string representations for each layer of the PSC device. These SMILES strings will be converted into numerical, vector representations/embeddings (by ChemBERTa) - which we will subsequently use to train both regression (for prediction) and generative models.
#
# 1. Converting the substrate, perovskite, ETL, HTL and backcontact layers/compositions into SMILES strings.

# %%
## version 1

import pandas as pd
import pubchempy as pcp
import re
from collections import defaultdict

# Define the columns of interest
psc_stack_columns = [
    'Perovskite_composition_a_ions', 'Perovskite_composition_b_ions', 
    'Perovskite_composition_c_ions', 'Substrate_stack_sequence', 
    'ETL_stack_sequence', 'HTL_stack_sequence', 'Backcontact_stack_sequence'
]

# Initialize a local cache for SMILES strings
smiles_cache = defaultdict(lambda: None)

# # Function to fetch SMILES strings for a list of unique ions
# def fetch_smiles(ions):
#     for ion in ions:
#         if ion not in smiles_cache:  # Avoid redundant API calls
#             try:
#                 compounds = pcp.get_compounds(ion, 'name')  # Query PubChem
#                 if compounds:
#                     smiles_cache[ion] = compounds[0].canonical_smiles
#                 else:
#                     print(f"No SMILES found for ion: {ion}")
#                     smiles_cache[ion] = None
#             except Exception as e:
#                 print(f"Error fetching SMILES for ion '{ion}': {e}")
#                 smiles_cache[ion] = None

# Function to convert ion strings to combined SMILES
def convert_to_smiles(ion_str):
    if pd.isna(ion_str) or str(ion_str).strip().lower() in ['none', '']:
        return None
    # Split ions by ; or |, and strip whitespace
    ions = [ion.strip() for ion in re.split(r'[;|]', ion_str)]
    # Fetch SMILES for each ion, skipping any that aren't found
    smiles_list = [smiles_cache[ion] for ion in ions if smiles_cache[ion] is not None]
    # Combine SMILES strings with a "." separator
    return '.'.join(smiles_list) if smiles_list else None

# Load your dataset (replace 'your_dataset.csv' with your actual file path)
df = pd.read_csv(r'C:\Users\c\OneDrive\Documents\PEROVSKITE PROJECT\PerovskiteML_project\Vector embedding\initial_cleaned_data.csv')

# Step 1: Extract all unique ions from the specified columns
all_ions = set()
for col in psc_stack_columns:
    if col in df.columns:  # Ensure the column exists in the dataset
        df[col].dropna().apply(lambda x: all_ions.update([ion.strip() for ion in re.split(r'[;|]', x)]))

# # Step 2: Fetch SMILES strings for all unique ions
# fetch_smiles(all_ions)

# # Step 3: Create new SMILES columns for each of the psc_stack_columns
# for col in psc_stack_columns:
#     if col in df.columns:  # Ensure the column exists
#         smiles_col = col + '_SMILES'
#         df[smiles_col] = df[col].apply(convert_to_smiles)

# # Save the updated dataframe to a new CSV file
# output_file_path = 'cleaned_data_with_smiles.csv'
# df.to_csv(output_file_path, index=False)

# # Print a preview of the dataframe
# print(df.head())

# print(f"Number of distinct ions: {len(all_ions)}")



# Initialize a list to store ions with no SMILES found
error_ions = []

# Function to fetch SMILES strings for a list of unique ions
def fetch_smiles(ions):
    for ion in ions:
        if ion not in smiles_cache:  # Avoid redundant API calls
            try:
                compounds = pcp.get_compounds(ion, 'name')  # Query PubChem
                if compounds and compounds[0].canonical_smiles:
                    smiles_cache[ion] = compounds[0].canonical_smiles
                else:
                    print(f"No SMILES found for ion: {ion}")
                    smiles_cache[ion] = None
                    error_ions.append(ion)  # Collect ion with no SMILES
            except Exception as e:
                print(f"Error fetching SMILES for ion '{ion}': {e}")
                smiles_cache[ion] = None
                error_ions.append(ion)  # Collect ion with fetch error

# After fetching SMILES, check error ions against the dataset
def check_error_ions_against_dataset(df, error_ions):
    ions_not_found_in_dataset = []
    for ion in error_ions:
        # Check if the ion is present in any column of the dataset
        columns_with_ion = df.columns[df.isin([ion]).any()].tolist()
        if not columns_with_ion:  # If the ion is not found in any column
            ions_not_found_in_dataset.append(ion)

    # Print the results
    print(f"Number of ions in the error message that are NOT present in the dataset: {len(ions_not_found_in_dataset)}")
    print(f"Ions not found in the dataset: {ions_not_found_in_dataset}")

# Example usage:
# unique_ions = df[psc_stack_columns].unique().tolist()  # Replace 'IonColumn' with the column containing ions# unique_ions = pd.unique(df[['IonColumn1', 'IonColumn2']].values.ravel()).tolist()
fetch_smiles(all_ions)  # Fetch SMILES and collect error ions
check_error_ions_against_dataset(df, error_ions)  # Check error ions against the dataset
# Out:
# C:\Users\c\AppData\Local\Temp\ipykernel_22404\2348563982.py:45: DtypeWarning: Columns (15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\c\OneDrive\Documents\PEROVSKITE PROJECT\PerovskiteML_project\Vector embedding\initial_cleaned_data.csv')
# No SMILES found for ion: 2PDI-4S
# No SMILES found for ion: AZO-np
# No SMILES found for ion: CuGaO2-np
# No SMILES found for ion: IDF-SFXPh
# No SMILES found for ion: PDI
# No SMILES found for ion: diPDI
# No SMILES found for ion: WPF‐6‐oxy‐F
# No SMILES found for ion: Poly(2-ethyl-2-oxazoline)
# No SMILES found for ion: C202
# No SMILES found for ion: TiO2-nanoplatelets
# No SMILES found for ion: (TEA)
# No SMILES found for ion: SGT-409
# No SMILES found for ion: CSCNT
# No SMILES found for ion: RE-ZnBu4Pc
# No SMILES found for ion: HBZ-70
# No SMILES found for ion: VB-DAAF
# No SMILES found for ion: pi-PFE4
# No SMILES found for ion: Poly(ethylene oxide)
# No SMILES found for ion: 1d @ triphenylamine modified azobenzene dyes
# No SMILES found for ion: TP1
# No SMILES found for ion: BL51
# No SMILES found for ion: PFN-OX
# No SMILES found for ion: H2-Chl
# No SMILES found for ion: Ta2O5
# No SMILES found for ion: 2FBTA-2
# No SMILES found for ion: Willow glas
# No SMILES found for ion: MgF2
# No SMILES found for ion: s-PANI:PSS
# No SMILES found for ion: M109
# No SMILES found for ion: PDMS
# No SMILES found for ion: Fullerene @ F3
# No SMILES found for ion: POZ9
# No SMILES found for ion: TPD-4MeOTPA
# No SMILES found for ion: PASP
# No SMILES found for ion: GFRHybrimer
# No SMILES found for ion: Au-grid
# No SMILES found for ion: Co0.878Cu0.122O
# No SMILES found for ion: Azu-Me
# No SMILES found for ion: DPIO
# No SMILES found for ion: PT-PDI
# No SMILES found for ion: HDAC
# No SMILES found for ion: J2
# No SMILES found for ion: po-TPE-4DPA
# No SMILES found for ion: Cu0.5Cr0.5O2
# No SMILES found for ion: PtMePy
# No SMILES found for ion: CuCo2O4
# No SMILES found for ion: DAHI
# No SMILES found for ion: PdMePy
# No SMILES found for ion: Z9
# No SMILES found for ion: BTPA-5
# No SMILES found for ion: NP-SC6-TiOPc
# No SMILES found for ion: V859
# No SMILES found for ion: 9,9'-([1,2,5]thiadiazolo[3,4-c]pyridine-4,7-diylbis(4,1- phenylene))bis(N3,N3,N6,N6-tetrakis(4-methoxyphenyl)-9H-carbazole-3,6-diamine)
# No SMILES found for ion: PDPP3T
# No SMILES found for ion: M113
# No SMILES found for ion: PSe-PDI
# No SMILES found for ion: PEDOT
# No SMILES found for ion: 4-(4-Phenyl-4-alfa-naphthylbutadienyl)-N,N-di(4-tolyl)-phenylamine
# No SMILES found for ion: HPB-Ome
# No SMILES found for ion: Polythiophene
# No SMILES found for ion: (f-PEA)
# No SMILES found for ion: SDTCz2F
# No SMILES found for ion: SnO2-nt
# No SMILES found for ion: Li4SiW12O40
# No SMILES found for ion: TPA-ANR-TPA
# No SMILES found for ion: 4,4'-(5,10,11-Trihexyl-10,11-dihydro-5H-thieno[2′,3':4,5]pyrrolo [3,2-g]thieno[3,2-b][1,2,3]triazolo[4,5-e]indole-2,8-diyl)bis(N,N-bis(4- methoxyphenyl)aniline)
# No SMILES found for ion: HTM-M1
# No SMILES found for ion: Ph-TPA-2A
# No SMILES found for ion: Au@TiO2-np
# No SMILES found for ion: ACE‐ANT‐ACE
# No SMILES found for ion: BAFB
# No SMILES found for ion: Me4NI
# No SMILES found for ion: HS-Ph-NO2
# No SMILES found for ion: TiO2-nanoflowers
# No SMILES found for ion: PC61BPy
# No SMILES found for ion: SnO2-nanospheres
# No SMILES found for ion: SBFCz2
# No SMILES found for ion: 1,3,6-tris-(N,N-di-p-methoxyphenylamine)pyrene
# No SMILES found for ion: PrCMA
# No SMILES found for ion: bis-C70
# No SMILES found for ion: ZnPc-th-ZnPc
# No SMILES found for ion: 0.97
# No SMILES found for ion: PEDOT:PSS:PSA
# No SMILES found for ion: (4AMPY)
# No SMILES found for ion: NDI-ID (RS)
# No SMILES found for ion: Th-OMeTPA
# No SMILES found for ion: Mg0.2Zn0.8O-np
# No SMILES found for ion: (PyrEA)
# No SMILES found for ion: BaSnO3-mp
# No SMILES found for ion: Sn2O3-qd
# No SMILES found for ion: MeO-BPZTPA
# No SMILES found for ion: M115
# No SMILES found for ion: C12-silane-SAM
# No SMILES found for ion: TATF8HBP
# No SMILES found for ion: Spiro-MeOTAD-I
# No SMILES found for ion: PEDOT:GSL
# No SMILES found for ion: Cyptop
# No SMILES found for ion: SAM1
# No SMILES found for ion: (ThMA)
# No SMILES found for ion: C60:PhIm
# No SMILES found for ion: EGO-PPV
# No SMILES found for ion: PhCOOH
# No SMILES found for ion: Polymer2
# No SMILES found for ion: BTP-1
# No SMILES found for ion: YVO4:Eu
# No SMILES found for ion: Q222
# No SMILES found for ion: PZn-2FTPA
# No SMILES found for ion: ZnS-QDs
# No SMILES found for ion: Cu2BaSnS4
# No SMILES found for ion: POZ2
# No SMILES found for ion: PTFTS
# No SMILES found for ion: CIGS
# No SMILES found for ion: NDI-BTH1
# No SMILES found for ion: XPP
# No SMILES found for ion: Z33
# No SMILES found for ion: CF-Sp-BTh
# No SMILES found for ion: CPE-Na
# No SMILES found for ion: ITO-nw
# No SMILES found for ion: In2O3:H
# No SMILES found for ion: BChl-3
# No SMILES found for ion: 4-(4-phenyl-4-alfa-naphthylbutadienyl)-N,N-di(4-methoxyphenyl)-phenylamine
# No SMILES found for ion: TiO2-nanowalls
# No SMILES found for ion: HCLaminate
# No SMILES found for ion: MeO-PheDOT
# No SMILES found for ion: Mg0.15Zn0.85O-np
# No SMILES found for ion: 2-((5-(4-(2-ethylhexyl)-4H-dithieno[3,2-b:2′,3′-d]pyrrol-2-yl) thiophen-2-yl)methylene) malononitrile
# No SMILES found for ion: 4-aminobenzoic acid-SAM
# No SMILES found for ion: PO-Spiro-OMeTAD
# No SMILES found for ion: Carbon black@5:1
# No SMILES found for ion: COTT-1
# No SMILES found for ion: ZnChl-3
# No SMILES found for ion: tert-CuBuPc
# No SMILES found for ion: 2TPA-3-DP
# No SMILES found for ion: I-Ph-PA_C60-C6-PA
# No SMILES found for ion: HOOC-C11H22-SH
# No SMILES found for ion: 4-(2-(4-(Bis(4-(hexyloxy)phenyl)methyl)phenyl)-9-methyl-9H-naphtho[2,1-c]carbazol-12-yl)-N,N-bis(4-(hexyloxy)phenyl)aniline
# No SMILES found for ion: PTZ1
# No SMILES found for ion: Carbon-np
# No SMILES found for ion: ZrAcAc
# No SMILES found for ion: IDT2
# No SMILES found for ion: Polycarbonate
# No SMILES found for ion: Ag@Au-np
# No SMILES found for ion: Polypseudorotaxane
# No SMILES found for ion: PAA
# No SMILES found for ion: Ba0.9Sr0.1SnO3-np
# No SMILES found for ion: TN
# No SMILES found for ion: PPDT2FBT
# No SMILES found for ion: ZnO-nanodisks
# No SMILES found for ion: H-FL
# No SMILES found for ion: CON-16
# No SMILES found for ion: TB-ZnPc
# No SMILES found for ion: CPEPh-Na
# No SMILES found for ion: BZnTPP
# No SMILES found for ion: TRUX1
# No SMILES found for ion: CzPF
# No SMILES found for ion: Spiro-CPDT
# No SMILES found for ion: (OdA)
# No SMILES found for ion: NDI
# No SMILES found for ion: 4-dimethoxybenzoic acid
# No SMILES found for ion: DPIE
# No SMILES found for ion: Sym-HTPcH
# No SMILES found for ion: PTB1
# No SMILES found for ion: Carbon-nt
# No SMILES found for ion: 2,6-Py
# No SMILES found for ion: TiO2-c @ {001} facet
# No SMILES found for ion: ZnO-nanowells
# No SMILES found for ion: NaI
# No SMILES found for ion: TTPA-BDT
# No SMILES found for ion: M112
# No SMILES found for ion: 2-((2-(4-(2-ethylhexyl)-4H-dithieno[3,2-b:2′,3′-d]pyrrol-2-yl) thiazol-5-yl)methylene) malononitrile
# No SMILES found for ion: 4,4′-(9-Methyl-9H-naphtho[2,1-c]carbazole-2,12-diyl)bis(N,N-bis(4-methoxyphenyl)aniline)
# No SMILES found for ion: PTCDI
# No SMILES found for ion: TiO2-c @ {101} facet
# No SMILES found for ion: NaYF4-np
# No SMILES found for ion: Ti3C2
# No SMILES found for ion: KM07
# No SMILES found for ion: TPE-DPP6
# No SMILES found for ion: PS-b-PEO
# No SMILES found for ion: 1,3,6,8-tetrakis-(N,N-di-p-methoxyphenylamine)pyrene
# No SMILES found for ion: SnO2-nw
# No SMILES found for ion: TCPI
# No SMILES found for ion: BT41
# No SMILES found for ion: ACR-TPA
# No SMILES found for ion: n-CuBuPc
# No SMILES found for ion: BTF4
# No SMILES found for ion: Ag-nanocubes
# No SMILES found for ion: CeOx-np
# No SMILES found for ion: Au@SnO2-np
# No SMILES found for ion: PDO1
# No SMILES found for ion: Poly TPD-NPD
# No SMILES found for ion: FT37
# No SMILES found for ion: Bis-FITG
# No SMILES found for ion: PDCBT
# No SMILES found for ion: Fulleropyrrolidinium Iodide
# No SMILES found for ion: DEA
# No SMILES found for ion: PN-F50
# No SMILES found for ion: Zeocoat
# No SMILES found for ion: alfa-NPD
# No SMILES found for ion: c-OTPD
# No SMILES found for ion: N2,N2,N2',N2',N7,N7,N7',N7'-octakis(4-methoxyphenyl)spiro[fluorene-9,9'-xanthene]-2,2',7,7'-tetraamine
# No SMILES found for ion: PEIA
# No SMILES found for ion: DIPO-Ph4
# No SMILES found for ion: PDIN
# No SMILES found for ion: N1,N1',N1'',N1'''-(ethene-1,1,2,2-tetrayltetrakis(benzene-4,1-diyl))tetrakis(N1-(4-(dimethylamino)phenyl)-N4,N4-dimethylbenzene-1,4-diamine)
# No SMILES found for ion: (n-C3H7NH3)
# No SMILES found for ion: CdSe-QD
# No SMILES found for ion: S,N-Heteroacene 1
# No SMILES found for ion: ZIF-8-10
# No SMILES found for ion: PCPDT-PDI
# No SMILES found for ion: 4,4'-((2-Hexyl-2H-benzo[d][1,2,3]triazole-4,7-diyl)bis(thiophene5,2-diyl))bis(N,N-bis(4-methoxyphenyl)aniline)
# No SMILES found for ion: ZnChl-4
# No SMILES found for ion: HOFP
# No SMILES found for ion: MPA-BTI
# No SMILES found for ion: AV-Carbon
# No SMILES found for ion: ZnO0.75Sn0.25O1.25
# No SMILES found for ion: PMDPT
# No SMILES found for ion: DPBTD-B[BMPDP]2
# No SMILES found for ion: p-DTS(FBTTh2)2
# No SMILES found for ion: 1,4-di(1H-imidazol-2-yl)benzene-C6
# No SMILES found for ion: SP-11
# No SMILES found for ion: Dompamin-SAM
# No SMILES found for ion: CuO-nw
# No SMILES found for ion: PEH-8
# No SMILES found for ion: F8T2e
# No SMILES found for ion: SGT-422
# No SMILES found for ion: P3HT
# No SMILES found for ion: MoO2-np
# No SMILES found for ion: TFSA-Graphene
# No SMILES found for ion: ZnPc
# No SMILES found for ion: a-DMEC70
# No SMILES found for ion: OEABS
# No SMILES found for ion: SM01
# No SMILES found for ion: PSS-g-PANI:PFI
# No SMILES found for ion: PCz
# No SMILES found for ion: Azu-Oct
# No SMILES found for ion: 3,6 ´-BCz-OMeTAD
# No SMILES found for ion: TAE3
# No SMILES found for ion: 3,8,13-tris[2,2-bis(4-methoxyphenyl)ethenyl]-5,10,15-triethyl-10,15-dihydro-5H-indolo-[3,2-a:3′,2′-c]carbazole
# No SMILES found for ion: PNVT-8
# No SMILES found for ion: 3-aminopropanioc acid-SAM
# No SMILES found for ion: Hexakis[4-(N,N-di-p-methoxyphenylamino)phenyl]benzene
# No SMILES found for ion: XSln847
# No SMILES found for ion: TTB3
# No SMILES found for ion: Me4NBr
# No SMILES found for ion: SrGeO3
# No SMILES found for ion: DI
# No SMILES found for ion: D101
# No SMILES found for ion: CuCrO2-np
# No SMILES found for ion: SiW11O39-POM
# No SMILES found for ion: 2,5-bis (5-(5-(5-hexylthiophen-2-yl) thiophen2-yl) thiophen-2-yl) thiazolo[5,4-d]thiazole
# No SMILES found for ion: YC-3
# No SMILES found for ion: ZIF-8-20
# No SMILES found for ion: TDPP-CN4
# No SMILES found for ion: 4,4'-(5,10,11-Trihexyl-10,11-dihydro-5H-thieno[2′,3':4,5]pyrrolo [3,2-g]thieno[3,2-b][1,2,3]triazolo[4,5-e]indole-2,8-diyl)bis(N,N-bis(4- (hexyloxy)phenyl)aniline)
# No SMILES found for ion: TAT-t BuSty
# No SMILES found for ion: ZnO-nanofibers
# No SMILES found for ion: Carbo-QDs
# No SMILES found for ion: rGO-flakes
# No SMILES found for ion: V842
# No SMILES found for ion: S197
# No SMILES found for ion: (HEA)
# No SMILES found for ion: 2,7-Cbz-EDOT
# No SMILES found for ion: HTM2
# No SMILES found for ion: none
# No SMILES found for ion: DDOF
# No SMILES found for ion: TPAC-SAM
# No SMILES found for ion: TPADPP-1
# No SMILES found for ion: PN-P
# No SMILES found for ion: BX-OMeTAD
# No SMILES found for ion: HB-Cz
# No SMILES found for ion: HAB1
# No SMILES found for ion: PN-F25
# No SMILES found for ion: Yih-1
# No SMILES found for ion: Zr(Acac)
# No SMILES found for ion: ATT-OBu
# No SMILES found for ion: Lignosulfonate
# No SMILES found for ion: V866
# No SMILES found for ion: Cu-tape
# No SMILES found for ion: TT80
# No SMILES found for ion: TbT-2
# No SMILES found for ion: Corrannulene-derivative
# No SMILES found for ion: 2,7-PCzTPA
# No SMILES found for ion: SGT-405
# No SMILES found for ion: ZrO2-np
# No SMILES found for ion: (2Z,2'Z)-2,2'-((10-(2-ethylhexyl)-10H-phenothiazine-3,7-diyl) bis(4,1- phenylene)) bis(3-(4-(diphenylamino) phenyl) acrylonitrile
# No SMILES found for ion: Spiro-OPrTAD
# No SMILES found for ion: CON-10
# No SMILES found for ion: ZnBChl
# No SMILES found for ion: 2,7-BCz-OMeTAD
# No SMILES found for ion: BV-FNPD
# No SMILES found for ion: Trux-OMeTAD
# No SMILES found for ion: p-(F)-PO-TAZ
# No SMILES found for ion: P-SC6-TiOPc
# No SMILES found for ion: CF-BTz-ThR
# No SMILES found for ion: H-Di
# No SMILES found for ion: Fullerene-2c
# No SMILES found for ion: TBC-3
# No SMILES found for ion: C60-MPy
# No SMILES found for ion: (NMA)
# No SMILES found for ion: CoCr
# No SMILES found for ion: NP-BC
# No SMILES found for ion: mDPA-DBTP
# No SMILES found for ion: TDT-OMeTAD
# No SMILES found for ion: NMBI
# No SMILES found for ion: PCBM-60-mp
# No SMILES found for ion: BTT-3
# No SMILES found for ion: 3,6-Cz-TPA
# No SMILES found for ion: CdSO
# No SMILES found for ion: CL1-2
# No SMILES found for ion: PCPDTBT
# No SMILES found for ion: Cellophane
# No SMILES found for ion: H-Tri
# No SMILES found for ion: s-Bphen
# No SMILES found for ion: N2,N2,N3',N3',N6',N6',N7,N7-octakis(4-methoxyphenyl)spiro[fluorene-9,9'-xanthene]-2,3',6',7-tetraamine
# No SMILES found for ion: TPB-2-MOTPA
# No SMILES found for ion: CuInS2@ZnS-QDs
# No SMILES found for ion: Th-PDI
# No SMILES found for ion: Ti-foil
# No SMILES found for ion: 3,6-Pyr
# No SMILES found for ion: CDTh-EtHex 2
# No SMILES found for ion: (DPA)
# No SMILES found for ion: CsSnBrI2-QDs
# No SMILES found for ion: Sb-Carbon-nw
# No SMILES found for ion: DMFA-TPA
# No SMILES found for ion: MgO-c
# No SMILES found for ion: BTF2
# No SMILES found for ion: (Ace)
# No SMILES found for ion: PEIE
# No SMILES found for ion: (H-PEA)
# No SMILES found for ion: Fe2O3-np
# No SMILES found for ion: Black phosphorous 2D
# No SMILES found for ion: MXene
# No SMILES found for ion: PTB8
# No SMILES found for ion: SnO2-c
# No SMILES found for ion: Cs-oleate
# No SMILES found for ion: IDF-DiDPA
# No SMILES found for ion: TPI-6MEO
# No SMILES found for ion: SnO
# No SMILES found for ion: CuPc-Bu
# No SMILES found for ion: PFBT-Na
# No SMILES found for ion: MUTAB-SAM
# No SMILES found for ion: Cu-CFN
# No SMILES found for ion: 2,2′-[(4,5-Bis(1-octylnonyl)-dithieno[2,3-d:2′3′-d]thieno[3,2-b:4,5-b′]dipyrrole-2,7-diyl)bis(thien-5,5′-diyl)bis(methane-1-yl-1-ylidine)]dimalononitrile
# No SMILES found for ion: PCBM-70
# No SMILES found for ion: CdZnSe@ZnSe-QDs
# No SMILES found for ion: Ppz
# No SMILES found for ion: TAZ-[MeOTPA]2
# No SMILES found for ion: [EMIM]PF6-IL
# No SMILES found for ion: PZn-TPA
# No SMILES found for ion: PETUG
# No SMILES found for ion: P:OO
# No SMILES found for ion: PTPD2
# No SMILES found for ion: Mono-PCBOE
# No SMILES found for ion: HTM1
# No SMILES found for ion: TPE-PDI4
# No SMILES found for ion: BTSe-1
# No SMILES found for ion: CZTS0.75Se0.25
# No SMILES found for ion: KR216
# No SMILES found for ion: TTPA-OMeTPA
# No SMILES found for ion: N3,N3,N9,N9‐tetrakis(4‐methoxyphenyl)xantheno[2,1,9,8‐klmna]xanthene‐3,9‐diamine
# No SMILES found for ion: OCA
# No SMILES found for ion: MoO3 ∣ ITO
# No SMILES found for ion: FNCA
# No SMILES found for ion: dly-1
# No SMILES found for ion: Zn2SnO4
# No SMILES found for ion: TPD-4MeTPA
# No SMILES found for ion: Q219
# No SMILES found for ion: IDIC
# No SMILES found for ion: V1050
# No SMILES found for ion: PDBD-T
# No SMILES found for ion: Cu9S5-np
# No SMILES found for ion: TOPD
# No SMILES found for ion: ADAHI
# No SMILES found for ion: resist
# No SMILES found for ion: F-PDI
# No SMILES found for ion: PEDOT:SAF
# No SMILES found for ion: (F5PEA)
# No SMILES found for ion: IDTC4-TPA
# No SMILES found for ion: FA-MeOPh
# No SMILES found for ion: CsF
# No SMILES found for ion: Poly(TA)
# No SMILES found for ion: X22
# No SMILES found for ion: PbZrTiO3
# No SMILES found for ion: CuSCN-3D
# No SMILES found for ion: Poly-EDOT-C60
# No SMILES found for ion: NaYF4:Yb:Tm-np
# No SMILES found for ion: PP-Spiro
# No SMILES found for ion: PANI-PAMPSA
# No SMILES found for ion: TTE-2
# No SMILES found for ion: S,Si‐heteropentacene
# No SMILES found for ion: PB(NAP-Th)TBT
# No SMILES found for ion: PhIm
# No SMILES found for ion: ZnCsO
# No SMILES found for ion: LT-TiO2:Cl
# No SMILES found for ion: NH2-POSS
# No SMILES found for ion: PTB9
# No SMILES found for ion: T30P
# No SMILES found for ion: SCPDT-BiT
# No SMILES found for ion: pSNT
# No SMILES found for ion: PTB7:Th
# No SMILES found for ion: MeO-DATPA
# No SMILES found for ion: HTM5
# No SMILES found for ion: FPI-PEIE
# No SMILES found for ion: H11
# No SMILES found for ion: Carbon-QDs
# No SMILES found for ion: SrGO
# No SMILES found for ion: PO-TAZ
# No SMILES found for ion: CuInS2-QDs
# No SMILES found for ion: 60
# No SMILES found for ion: SnS-np
# No SMILES found for ion: PBDTT
# No SMILES found for ion: ATT-OMe
# No SMILES found for ion: Si-OMeTPA
# No SMILES found for ion: ITO-HMDS Scaffold
# No SMILES found for ion: COi8DFIC
# No SMILES found for ion: WY-2
# No SMILES found for ion: (N-EtPy)
# No SMILES found for ion: Cu2MnSn4-np
# No SMILES found for ion: TiO2-nw
# No SMILES found for ion: C12H10B2O4
# No SMILES found for ion: ZrO2-c
# No SMILES found for ion: SGT-420
# No SMILES found for ion: NO-Graphene-QDs
# No SMILES found for ion: (4FPEA)
# No SMILES found for ion: KI
# No SMILES found for ion: Q197
# No SMILES found for ion: C6TBPH2
# No SMILES found for ion: DNA-CTMA
# No SMILES found for ion: 2,5-bis (5-(5-(5-hexylthiophen-2-yl)thiophen-2-yl) furan-2-yl) thiazolo[5,4-d] thiazole
# No SMILES found for ion: DA
# No SMILES found for ion: PES
# No SMILES found for ion: PDI-HE
# No SMILES found for ion: C3-SAM
# No SMILES found for ion: 1,2-ethanedithiol (10 mM)
# No SMILES found for ion: BTPA-6
# No SMILES found for ion: TBC-2
# No SMILES found for ion: PDPP-3T
# No SMILES found for ion: CuSCN-2D
# No SMILES found for ion: F8TBT
# No SMILES found for ion: TTPA-DTP
# No SMILES found for ion: P1Z2
# No SMILES found for ion: PPDI-F3N
# No SMILES found for ion: Ps
# No SMILES found for ion: CISZ-QDs
# No SMILES found for ion: PffBT4T-20D
# No SMILES found for ion: Fullerene @ F1
# No SMILES found for ion: FBT-TH4
# No SMILES found for ion: PCP-Na
# No SMILES found for ion: Carbon-tape
# No SMILES found for ion: YC01
# No SMILES found for ion: HS-Ph-CN
# No SMILES found for ion: (TMA)
# No SMILES found for ion: TET
# No SMILES found for ion: Me6-ZnPc
# No SMILES found for ion: Pt-Carbon-nt
# No SMILES found for ion: Ti-grid
# No SMILES found for ion: MoO3 ∣ Au ∣ Ag ∣ MoO3
# No SMILES found for ion: PTTh
# No SMILES found for ion: Cu0.67Cr0.33O2
# No SMILES found for ion: MoOx-np
# No SMILES found for ion: 2,7-Pyr
# No SMILES found for ion: NH-2,6
# No SMILES found for ion: FBA2
# No SMILES found for ion: Bi2Te3
# No SMILES found for ion: apv-EC
# No SMILES found for ion: (NH4)
# No SMILES found for ion: BU
# No SMILES found for ion: TiO2-3D
# No SMILES found for ion: Cz-Pyr
# No SMILES found for ion: TiZnO12-c
# No SMILES found for ion: Spiro-029
# No SMILES found for ion: P2Z1
# No SMILES found for ion: PDVT-10
# No SMILES found for ion: BTPA-3
# No SMILES found for ion: ZnPc-DPP-ZnPc
# No SMILES found for ion: EtheneDTPA
# No SMILES found for ion: PDTP-DFBT:PCBM-60
# No SMILES found for ion: MCA
# No SMILES found for ion: TPA-BPFN-TPA
# No SMILES found for ion: AZ1
# No SMILES found for ion: 2,2'-[(4,5-Bis(2-ethylhexyl)-dithieno[2,3-d:2',3'-d']thieno[3,2-b:4,5-b']dipyrrole-2,7-diyl)-bis(3-hexylthien-5,5'-diyl)bis(methane-1-yl-1-ylidine)]dimalononitrile
# No SMILES found for ion: PV-PDI
# No SMILES found for ion: Ph-TPM
# No SMILES found for ion: PTZ2
# No SMILES found for ion: PDBT-co-TT
# No SMILES found for ion: SY1
# No SMILES found for ion: Al2O3-c
# No SMILES found for ion: KR122
# No SMILES found for ion: Ag-mesh:PH1000
# No SMILES found for ion: ZnSnO4-c
# No SMILES found for ion: ZnPc(tBu)4
# No SMILES found for ion: N-[3-(Trimethoxysilyl)propyl]ethylenediamine-SAM
# No SMILES found for ion: Mo(tfd-COCF3)3
# No SMILES found for ion: H6
# No SMILES found for ion: TiO2-nanofibres
# No SMILES found for ion: TPL
# No SMILES found for ion: DERDTS-TBDT
# No SMILES found for ion: CSOE
# No SMILES found for ion: BP-DC
# No SMILES found for ion: VB-MeO-FDPA
# No SMILES found for ion: PCBM-60
# No SMILES found for ion: SnO2-np
# No SMILES found for ion: YD2-o-C8
# No SMILES found for ion: Yih-2
# No SMILES found for ion: 4b @ triphenylamine modified azobenzene dyes
# No SMILES found for ion: Silica gel electrolyte
# No SMILES found for ion: Cu-BHT
# No SMILES found for ion: PBTTT-14
# No SMILES found for ion: ITO
# No SMILES found for ion: CMO
# No SMILES found for ion: 5-AVA
# No SMILES found for ion: Zn2Ti3O8-mp
# No SMILES found for ion: (5-AVAI)
# No SMILES found for ion: Fullerene @ F4
# No SMILES found for ion: HS-Ph-OCH3
# No SMILES found for ion: DFH
# No SMILES found for ion: T102
# No SMILES found for ion: 0F
# No SMILES found for ion: BDT-4D
# No SMILES found for ion: Cu:NiO-np
# No SMILES found for ion: IT-M
# No SMILES found for ion: TPA4C
# No SMILES found for ion: CS05
# No SMILES found for ion: PDBS-PDI
# No SMILES found for ion: M4
# No SMILES found for ion: m-PYBrZnPor
# No SMILES found for ion: Nb2O5-mp
# No SMILES found for ion: CZTPA-2
# No SMILES found for ion: NaPTH
# No SMILES found for ion: PTB7
# No SMILES found for ion: CPE-K
# No SMILES found for ion: CDIN
# No SMILES found for ion: MoS2-QDs
# No SMILES found for ion: TbT-1
# No SMILES found for ion: NDI-PM
# No SMILES found for ion: D149
# No SMILES found for ion: InP-np
# No SMILES found for ion: 2-PA-SAM
# No SMILES found for ion: MEH-PPV
# No SMILES found for ion: PCB-C12
# No SMILES found for ion: AL2O3-c
# No SMILES found for ion: 2D-Sb
# No SMILES found for ion: FTA2
# No SMILES found for ion: NTPA
# No SMILES found for ion: TPA-CN
# No SMILES found for ion: Poly-N-vinylcarbazole
# No SMILES found for ion: S,N-heteropentacene
# No SMILES found for ion: Y2A2
# No SMILES found for ion: PTZ-2
# No SMILES found for ion: BiFeO3
# No SMILES found for ion: Cu2NiSn4-np
# No SMILES found for ion: C12-carbazole
# No SMILES found for ion: CuIn1.5Se3-QDs
# No SMILES found for ion: WO3
# No SMILES found for ion: COTT-2
# No SMILES found for ion: BaTiO3-mp
# No SMILES found for ion: Ph-inv-OMeTPA
# No SMILES found for ion: HS-Ph-SCH3
# No SMILES found for ion: FA-PDI2
# No SMILES found for ion: FSIP
# No SMILES found for ion: V1036:C2
# No SMILES found for ion: CsSnBr3-QDs
# No SMILES found for ion: (2Z,2′Z)-3,3′- (5,5′-(2,7-dioctyl-1,3,6,8-tetraoxo-1,2,3,6,7,8-hexahydrobenzo [lmn][3,8]phenanthroline-4,9-diyl)bis (thiophene-5,2-diyl))bis(2-(4-(trifluoromethyl)phenyl) acrylonitrile)
# No SMILES found for ion: TPA-Pc
# No SMILES found for ion: PVBT-TMA
# No SMILES found for ion: PHPT-py
# No SMILES found for ion: C60-HPy
# No SMILES found for ion: (TBA)
# No SMILES found for ion: OIPC-Br
# No SMILES found for ion: CZTS0.25Se0.75
# No SMILES found for ion: [BMPA-BTD]3-TPA
# No SMILES found for ion: P(BDTT-SePPD)
# No SMILES found for ion: Zn(acac)
# No SMILES found for ion: PZn-DPPA
# No SMILES found for ion: YC04
# No SMILES found for ion: DPC60
# No SMILES found for ion: (BZA)
# No SMILES found for ion: PVBT-SO3
# No SMILES found for ion: EA
# No SMILES found for ion: BTF1
# No SMILES found for ion: Al2O3
# No SMILES found for ion: Cu3PS4-np
# No SMILES found for ion: PCA-1
# No SMILES found for ion: Spiro-MeO-TPD
# No SMILES found for ion: PFN-Ox
# No SMILES found for ion: BaTiO3
# No SMILES found for ion: TPBC
# No SMILES found for ion: NDIF1
# No SMILES found for ion: (SCN)
# No SMILES found for ion: Z10
# No SMILES found for ion: BTT-OMe
# No SMILES found for ion: P3HT-MoS2
# No SMILES found for ion: PCBB-2CN-2C8
# No SMILES found for ion: Sb2O3-np
# No SMILES found for ion: CzPAF-TPA
# No SMILES found for ion: PBTTT
# No SMILES found for ion: Me-BPZTPA
# No SMILES found for ion: BTT-Me
# No SMILES found for ion: Rodhamine 101
# No SMILES found for ion: PTZDPP-2
# No SMILES found for ion: TTF1
# No SMILES found for ion: PCBB-3N-3I
# No SMILES found for ion: NDI-BiSe
# No SMILES found for ion: Phen-NaDPO:Sn(SCN)2
# No SMILES found for ion: CBA-SAM
# No SMILES found for ion: SGT-410
# No SMILES found for ion: TPB-4-MOTPA
# No SMILES found for ion: Cu0.2Cr0.8O2
# No SMILES found for ion: T2CA
# No SMILES found for ion: PbS
# No SMILES found for ion: PCBCB
# No SMILES found for ion: MPA-BTTI
# No SMILES found for ion: ZnS-np
# No SMILES found for ion: Polymer3
# No SMILES found for ion: 4C
# No SMILES found for ion: BL52
# No SMILES found for ion: DORDTS–TFBT
# No SMILES found for ion: DNDIF3
# No SMILES found for ion: CrO2
# No SMILES found for ion: XDB
# No SMILES found for ion: NP1
# No SMILES found for ion: B3
# No SMILES found for ion: M108
# No SMILES found for ion: V1221
# No SMILES found for ion: Ta2O3
# No SMILES found for ion: 4,8-bis-(5-bromothiophene-2-yl)-benzo thiadiazole
# No SMILES found for ion: Polyethylene glycol
# No SMILES found for ion: IT4H
# No SMILES found for ion: HATNA-F6
# No SMILES found for ion: TPD-4EtCz
# No SMILES found for ion: Foil
# No SMILES found for ion: EP02
# No SMILES found for ion: PBDT(T)(2F)T
# No SMILES found for ion: BSO-mp
# No SMILES found for ion: PCBM-60-MCM
# No SMILES found for ion: DTPC8-ThTPA
# No SMILES found for ion: YC02
# No SMILES found for ion: SCZF-5
# No SMILES found for ion: CDTh 1
# No SMILES found for ion: (DTYM-NDI-DTYA)2
# No SMILES found for ion: (EDA)
# No SMILES found for ion: ZnO-nanoflake
# No SMILES found for ion: f-C70
# No SMILES found for ion: PCBM-62
# No SMILES found for ion: (Anyl)
# No SMILES found for ion: V1021
# No SMILES found for ion: IDT6CN-4F
# No SMILES found for ion: PBDTTT-E-T
# No SMILES found for ion: N2,N,N8,N8-tetrakis[2,2-bis(4-methoxyphenyl)ethenyl]-4,10-dimethyl-6H,12H-5,11-methanodibenzo[b,f][1,5]diazocine2,8-diamine
# No SMILES found for ion: C60-5c
# No SMILES found for ion: ITCP-M
# No SMILES found for ion: pi-PFE2
# No SMILES found for ion: rGO:TiO2-nanofibrse
# No SMILES found for ion: OMeTP-SAM
# No SMILES found for ion: In2O3
# No SMILES found for ion: 2-HI-PVK
# No SMILES found for ion: CsPbBr3-np
# No SMILES found for ion: 3,4-b′]dithiophene
# No SMILES found for ion: TiO2-nanobeads
# No SMILES found for ion: Au-nw
# No SMILES found for ion: Bis-FIMG
# No SMILES found for ion: CAS
# No SMILES found for ion: X61
# No SMILES found for ion: SnO2-nanosheets
# No SMILES found for ion: C5-NCMA
# No SMILES found for ion: CuEtPc
# No SMILES found for ion: 1-(N,N-di-p-methoxyphenylamine)pyrene
# No SMILES found for ion: ZnMgO-c
# No SMILES found for ion: Carbon-nt-yarn
# No SMILES found for ion: Ag-np
# No SMILES found for ion: CZ-STA
# No SMILES found for ion: Cu12Sb4S13
# No SMILES found for ion: CdZnSeS-QDs
# No SMILES found for ion: CuMePy
# No SMILES found for ion: MnO3
# No SMILES found for ion: C60-BCT-Au-NP
# No SMILES found for ion: CZTS
# No SMILES found for ion: KR378
# No SMILES found for ion: Ti-wire
# No SMILES found for ion: Nanopaper
# No SMILES found for ion: MoS2-nanosheets
# No SMILES found for ion: S-acetylthiocholine chlorde
# No SMILES found for ion: PD-10-DTTE-7
# No SMILES found for ion: d-PCBM-60
# No SMILES found for ion: ZnMe2Pc
# No SMILES found for ion: PCBB-OEG
# No SMILES found for ion: CuHePc
# No SMILES found for ion: PEH-3
# No SMILES found for ion: NiMgO
# No SMILES found for ion: TPA2C
# No SMILES found for ion: TPA-BPV-TPA
# No SMILES found for ion: 1,6-di{3-[2-(4- methylphenyl)vinyl]carbazol-9-yl}hexane
# No SMILES found for ion: 2,7-Bis(4,4′-dimethoxydiphenylamine)-9- (bis(methylsulfanyl)methylene)fluorene
# No SMILES found for ion: TTB2
# No SMILES found for ion: ABA-SAM
# No SMILES found for ion: TEAI
# No SMILES found for ion: H-Ca
# No SMILES found for ion: CuBuPc
# No SMILES found for ion: PTO
# No SMILES found for ion: PPDIN6
# No SMILES found for ion: BACl
# No SMILES found for ion: 3,3'-(2,7-bis(bis(4-methoxyphenyl)amino)-9H-fluorene-9,9-diyl)bis(N-ethyl-N,N- dimethylpropan-1-aminium) bis(trifluoromethanesulfonyl)imide
# No SMILES found for ion: SFXDAnCBZ
# No SMILES found for ion: Z1
# No SMILES found for ion: PDTSTTz
# No SMILES found for ion: Au@TiO2-nw
# No SMILES found for ion: BL50
# No SMILES found for ion: Si-QDs
# No SMILES found for ion: (3AMPY)
# No SMILES found for ion: PDAI
# No SMILES found for ion: DH-MeO-FDPA
# No SMILES found for ion: (IEA)
# No SMILES found for ion: SLG-HAMC-patterned
# No SMILES found for ion: EHCz-MeFl
# No SMILES found for ion: Cs4SnO4
# No SMILES found for ion: TiO2-IO
# No SMILES found for ion: (mF1PEA)
# No SMILES found for ion: C60/C70-N
# No SMILES found for ion: NiO-nanowalls
# No SMILES found for ion: CeO2-c
# No SMILES found for ion: NiMgO-c
# No SMILES found for ion: PTPAANT
# No SMILES found for ion: BDT-PTZ
# No SMILES found for ion: IPH
# No SMILES found for ion: FDT
# No SMILES found for ion: PEDOT:PSSl
# No SMILES found for ion: AuAg
# No SMILES found for ion: Azu-EH
# No SMILES found for ion: HTM-1
# No SMILES found for ion: SFX-PDI4
# No SMILES found for ion: AQ310
# No SMILES found for ion: M7-Br
# No SMILES found for ion: Au@Ag
# No SMILES found for ion: JK-217D
# No SMILES found for ion: NDT
# No SMILES found for ion: Filed's metal
# No SMILES found for ion: AgAu-np
# No SMILES found for ion: Fused-F (Tris[[4-[3,3'-dihexylsilylene-2,2'-bithiophene]-7-[5′′-n-hexyl-(2,2′
# No SMILES found for ion: P3OT
# No SMILES found for ion: SGT-407
# No SMILES found for ion: Si-nw
# No SMILES found for ion: Si-np
# No SMILES found for ion: ZnSO4-mp
# No SMILES found for ion: PDO2
# No SMILES found for ion: M101
# No SMILES found for ion: TPFB
# No SMILES found for ion: TP-FTzF-TP
# No SMILES found for ion: CzPAF‐SBFN
# No SMILES found for ion: TEACl
# No SMILES found for ion: V2Ox
# No SMILES found for ion: Br-BPA-SAM
# No SMILES found for ion: AUH
# No SMILES found for ion: TATSFHBP
# No SMILES found for ion: SLG
# No SMILES found for ion: BTT(DPP)3-C8
# No SMILES found for ion: Y2
# No SMILES found for ion: 1‐adamantylamine
# No SMILES found for ion: P3CT-Na
# No SMILES found for ion: TPA-BP-TPA
# No SMILES found for ion: VB-Me-FDPA
# No SMILES found for ion: (pF1PEA)
# No SMILES found for ion: 2EGO-PPV
# No SMILES found for ion: PPyra-ACD
# No SMILES found for ion: 2PDI-0S
# No SMILES found for ion: ACE-QA-ACE
# No SMILES found for ion: ZnCdS
# No SMILES found for ion: b-CNF
# No SMILES found for ion: 2,5‐bis(4,4′‐bis(methoxyphenyl)aminophen‐4′′‐yl)‐3,4‐ethylenedioxythiophene
# No SMILES found for ion: TTz-1
# No SMILES found for ion: Ag@TiO2-np
# No SMILES found for ion: A-PDTON
# No SMILES found for ion: HATNAS3C7
# No SMILES found for ion: Cu3SbS4-np
# No SMILES found for ion: C60-ETA
# No SMILES found for ion: SWCNTs
# No SMILES found for ion: Aa
# No SMILES found for ion: bis-C60
# No SMILES found for ion: CuInS
# No SMILES found for ion: beta-Alanine-SAM
# No SMILES found for ion: CS04
# No SMILES found for ion: PET-OMeDPA
# No SMILES found for ion: pPh-2MODPACz
# No SMILES found for ion: PrC60MAI
# No SMILES found for ion: 2,7-Ben
# No SMILES found for ion: ZnPy
# No SMILES found for ion: bis-PCBOE
# No SMILES found for ion: TPAC2M
# No SMILES found for ion: HATNASO2C7-Cs
# No SMILES found for ion: PBDTP-DTDPP
# No SMILES found for ion: ZnO0.855Sn0.15O1.15
# No SMILES found for ion: NiO-np
# No SMILES found for ion: ZnChl-1
# No SMILES found for ion: V1056
# No SMILES found for ion: Py-C
# No SMILES found for ion: P3DDT
# No SMILES found for ion: NaYF4
# No SMILES found for ion: Chl‐2
# No SMILES found for ion: Polystyrene
# No SMILES found for ion: DMEC-70
# No SMILES found for ion: PB2T-SO
# No SMILES found for ion: BTPA-TCNE
# No SMILES found for ion: IDT1
# No SMILES found for ion: PANI
# No SMILES found for ion: THY-5
# No SMILES found for ion: Plastic foam
# No SMILES found for ion: SrTiO3-c
# No SMILES found for ion: HATNAS3C4
# No SMILES found for ion: ACO-c
# No SMILES found for ion: Ce2O-mp
# No SMILES found for ion: TPASBP
# No SMILES found for ion: Z1012
# No SMILES found for ion: Black P-QDs
# No SMILES found for ion: YKP06
# No SMILES found for ion: NO HTL
# No SMILES found for ion: C60-BPy
# No SMILES found for ion: P3OFHT
# No SMILES found for ion: V1036:C4
# No SMILES found for ion: LHTM-1
# No SMILES found for ion: ICTA
# No SMILES found for ion: 2PDI-2S
# No SMILES found for ion: SiO2-hollow
# No SMILES found for ion: PVAc
# No SMILES found for ion: DPA-QA-DPA
# No SMILES found for ion: Z1013
# No SMILES found for ion: r-GO-BH
# No SMILES found for ion: TN-P
# No SMILES found for ion: TDTP
# No SMILES found for ion: CuxO
# No SMILES found for ion: Tetrakis-Triphenylamine
# No SMILES found for ion: BTT(DPP-Th)3-EH
# No SMILES found for ion: Organosilicate
# No SMILES found for ion: ICPA
# No SMILES found for ion: ZnTiO3-c
# No SMILES found for ion: Au-wire
# No SMILES found for ion: TTA1
# No SMILES found for ion: pi-PFE1
# No SMILES found for ion: 3,6-Ben
# No SMILES found for ion: ZnO0.95Sn0.05O1.05
# No SMILES found for ion: tri-TPA
# No SMILES found for ion: Ca(acac)2
# No SMILES found for ion: (PDMA)
# No SMILES found for ion: Unknown
# No SMILES found for ion: (CIEA)
# No SMILES found for ion: PTB-BO
# No SMILES found for ion: Zn-Chl
# No SMILES found for ion: SLNOA63
# No SMILES found for ion: Na3C6H5O7
# No SMILES found for ion: Steel
# No SMILES found for ion: Ph-OMeTPA
# No SMILES found for ion: P1
# No SMILES found for ion: V873
# No SMILES found for ion: pBTT
# No SMILES found for ion: Zr(AcAc)
# No SMILES found for ion: CuI
# No SMILES found for ion: TmTyPB
# No SMILES found for ion: HATNAS3C7-C3h
# No SMILES found for ion: ZnO-nanospheres
# No SMILES found for ion: Mg0.1Zn0.9O-np
# No SMILES found for ion: C60-BCT
# No SMILES found for ion: Triazine-Th-OMeTPA
# No SMILES found for ion: CsBiBr3-QDs
# No SMILES found for ion: SM09
# No SMILES found for ion: MC8-9-NPC
# No SMILES found for ion: Regenerated cellulose film
# No SMILES found for ion: DFTAB
# No SMILES found for ion: ZnO0.85Sn0.2O1.2
# No SMILES found for ion: TPB(2-MeOTAD)
# No SMILES found for ion: DR3T
# No SMILES found for ion: LiI
# No SMILES found for ion: MgZnO
# No SMILES found for ion: MHGO
# No SMILES found for ion: Br-BA
# No SMILES found for ion: cyclopenta[2,1-b
# No SMILES found for ion: TFDIB
# No SMILES found for ion: Tris(4-(5-hexylthiophen-2-yl)phenyl)amine
# No SMILES found for ion: DPA-TPM
# No SMILES found for ion: SnZnO
# No SMILES found for ion: Au@SiO2-np
# No SMILES found for ion: TPE-2,7-Carbazole W4
# No SMILES found for ion: F22
# No SMILES found for ion: CH3O-PEIA
# No SMILES found for ion: G1
# No SMILES found for ion: NDI-ID (RR)
# No SMILES found for ion: 1,3-disubstituted azulene
# No SMILES found for ion: CsSnI2.95F0.05
# No SMILES found for ion: DMEC-60
# No SMILES found for ion: CZ-TA
# No SMILES found for ion: NaYF4:Yb:Er-np
# No SMILES found for ion: Me2N-DATPA
# No SMILES found for ion: V1013
# No SMILES found for ion: TATCz3
# No SMILES found for ion: SnS2
# No SMILES found for ion: Nafion
# No SMILES found for ion: CS01
# No SMILES found for ion: TBASBP
# No SMILES found for ion: H4
# No SMILES found for ion: ZrO2-mp
# No SMILES found for ion: TPP-OMeTAD
# No SMILES found for ion: TPE-DPP16
# No SMILES found for ion: COPV4
# No SMILES found for ion: IPB
# No SMILES found for ion: PAF-86
# No SMILES found for ion: WO3-np
# No SMILES found for ion: T60P
# No SMILES found for ion: M117
# No SMILES found for ion: BPZTPA
# No SMILES found for ion: N2,N2,N12,N12-Tetrakis(4-methoxyphenyl)-9-methyl-9H-naphtho[2,1-c]carbazole-2,12-diamine
# No SMILES found for ion: 4-DMABA
# No SMILES found for ion: Au@SnO2-nw
# No SMILES found for ion: TTh101
# No SMILES found for ion: HTM4
# No SMILES found for ion: Co0.817Cu0.183O
# No SMILES found for ion: NO2-PEIA
# No SMILES found for ion: PT-DC
# No SMILES found for ion: Ag@TiO2-nw
# No SMILES found for ion: Cu(In0.5Ga0.5)S2-np
# No SMILES found for ion: AgZn
# No SMILES found for ion: EHCz-2EtCz
# No SMILES found for ion: CH3-PEIA
# No SMILES found for ion: ETH44
# No SMILES found for ion: TPA-TVT-TPA
# No SMILES found for ion: UiO-66
# No SMILES found for ion: BCP
# No SMILES found for ion: Nb2O5-c
# No SMILES found for ion: TiO2-nanobundles
# No SMILES found for ion: C60-5d
# No SMILES found for ion: TT-2,5-TPA
# No SMILES found for ion: Al3O3-mp
# No SMILES found for ion: SrSnO3
# No SMILES found for ion: N749
# No SMILES found for ion: 2,2'-[(4,5-Bis(2-ethylhexyl)-dithieno[2,3-d:2',3'-d']thieno[3,2-b:4,5-b']dipyrrole-2,7-diyl)-bis(4,3'-dihexyl-2,2'-bithien-5,5'-diyl)bis(methane-1-yl-1-ylidine)]dimalononitrile
# No SMILES found for ion: TAZ-[MeOTPATh]2
# No SMILES found for ion: (PF6)
# No SMILES found for ion: BTT-1
# No SMILES found for ion: SnO2-mp
# No SMILES found for ion: PCBM-derivative12
# No SMILES found for ion: 1,2-ethanedithiol (15 mM)
# No SMILES found for ion: Cu-grid
# No SMILES found for ion: X14
# No SMILES found for ion: Ba0.8Sr0.2SnO3-np
# No SMILES found for ion: Spiro-TBB
# No SMILES found for ion: 2D-PT
# No SMILES found for ion: ADAHCl
# No SMILES found for ion: CSCNT@SnO2
# No SMILES found for ion: PBDT(2F)T
# No SMILES found for ion: NiCoO
# No SMILES found for ion: DPP-F
# No SMILES found for ion: 2F-SAM
# No SMILES found for ion: Z7
# No SMILES found for ion: TSHBC
# No SMILES found for ion: CsPbI3-QD
# No SMILES found for ion: (PBA)
# No SMILES found for ion: 2TPA-1-DP
# No SMILES found for ion: NBA-SAM
# No SMILES found for ion: KM03
# No SMILES found for ion: ZnSnO4-mp
# No SMILES found for ion: BaSnO3-np
# No SMILES found for ion: PPDIDTT
# No SMILES found for ion: TPADPP-2
# No SMILES found for ion: CoTh-TTPA
# No SMILES found for ion: PABA-SAM
# No SMILES found for ion: PEI (CAS # 61128-46-9)
# No SMILES found for ion: CuInS2
# No SMILES found for ion: MPTMS-SMA
# No SMILES found for ion: TZ-1
# No SMILES found for ion: nc-TiO2
# No SMILES found for ion: PbS-QDs
# No SMILES found for ion: Diazo-OMeTPA
# No SMILES found for ion: (4AMP)I2
# No SMILES found for ion: V1000
# No SMILES found for ion: CzP
# No SMILES found for ion: H6-ZnPc
# No SMILES found for ion: iDM1
# No SMILES found for ion: TRUX-E-T
# No SMILES found for ion: DMAPA-C60
# No SMILES found for ion: DTP-C6Th
# No SMILES found for ion: PolyTDP
# No SMILES found for ion: PPP
# No SMILES found for ion: FBA3
# No SMILES found for ion: CuMePc
# No SMILES found for ion: TPB
# No SMILES found for ion: TRUX2
# No SMILES found for ion: TAE1
# No SMILES found for ion: Au@CuZnSnSe-np
# No SMILES found for ion: ZnO@SnO2-np
# No SMILES found for ion: ICBA-tran3
# No SMILES found for ion: ZnOS
# No SMILES found for ion: CdSe-Qd
# No SMILES found for ion: TTB-TTQ
# No SMILES found for ion: (ImEA)
# No SMILES found for ion: Polyester-satin textile
# No SMILES found for ion: PPNBr
# No SMILES found for ion: NPC60 OH
# No SMILES found for ion: M:OO
# No SMILES found for ion: ICMA
# No SMILES found for ion: BTT-TPA
# No SMILES found for ion: 3EGO-PPV
# No SMILES found for ion: Zn2SnO4-fiber
# No SMILES found for ion: (Br-PEA)
# No SMILES found for ion: pDPA-DBTP
# No SMILES found for ion: Zn0.8Cd0.2S-np
# No SMILES found for ion: In2S3
# No SMILES found for ion: HTM-2
# No SMILES found for ion: DPA-ANR-DPA
# No SMILES found for ion: H112
# No SMILES found for ion: DTPC8-ThDTPA
# No SMILES found for ion: DPP-Ome
# No SMILES found for ion: PZn-TPA-O
# No SMILES found for ion: PDPP-DTT
# No SMILES found for ion: HTB-Ome
# No SMILES found for ion: JK-216D
# No SMILES found for ion: CuPc(tBu)4
# No SMILES found for ion: P3TI
# No SMILES found for ion: TPE-DPP4
# No SMILES found for ion: (n-BuO)4ZnPc
# No SMILES found for ion: MTPS-SAM
# No SMILES found for ion: TPACA
# No SMILES found for ion: Cs2SnI6
# No SMILES found for ion: TMPA-Cl
# No SMILES found for ion: Cu phtalocyanine
# No SMILES found for ion: PS
# No SMILES found for ion: Cu:Ni acetate
# No SMILES found for ion: Cu:NiO
# No SMILES found for ion: Poly(1,4-phenylenevinylene)
# No SMILES found for ion: Sr2CeO4:Sm
# No SMILES found for ion: LiMgNiO
# No SMILES found for ion: ZnPc-p-ZnPc
# No SMILES found for ion: V1225
# No SMILES found for ion: V911
# No SMILES found for ion: CZTS0.5Se0.5
# No SMILES found for ion: PSQ2
# No SMILES found for ion: NbOx
# No SMILES found for ion: SiO2-np
# No SMILES found for ion: Graphene-QDs
# No SMILES found for ion: B2F
# No SMILES found for ion: MgO-EA
# No SMILES found for ion: C5PcH2
# No SMILES found for ion: V1036
# No SMILES found for ion: HTAB
# No SMILES found for ion: PFN-P2
# No SMILES found for ion: TPA-ZnPc
# No SMILES found for ion: Spiro-s
# No SMILES found for ion: OCNR
# No SMILES found for ion: THY-1
# No SMILES found for ion: Triazine-Flu
# No SMILES found for ion: PCBDANI
# No SMILES found for ion: Al2O3-nt
# No SMILES found for ion: FH-3
# No SMILES found for ion: INVAR
# No SMILES found for ion: IT4M
# No SMILES found for ion: Br-PDI
# No SMILES found for ion: L-H
# No SMILES found for ion: B2Cat2
# No SMILES found for ion: (DAP)
# No SMILES found for ion: IM
# No SMILES found for ion: TPA-QA-TPA
# No SMILES found for ion: AlAg
# No SMILES found for ion: Au-np
# No SMILES found for ion: MATS
# No SMILES found for ion: HTM3
# No SMILES found for ion: (PyEA)
# No SMILES found for ion: PDBT-T1
# No SMILES found for ion: Epoxy
# No SMILES found for ion: TiO2-nanofibers
# No SMILES found for ion: CZTSSe
# No SMILES found for ion: Ag-nanocube
# No SMILES found for ion: Graphene nanoribbons hPDI2-Pyr-hPDI2
# No SMILES found for ion: ZnO-c
# No SMILES found for ion: EFGnPs-F
# No SMILES found for ion: P3TMAHT
# No SMILES found for ion: Mg0.05Zn0.95O-np
# No SMILES found for ion: DPO
# No SMILES found for ion: KR360
# No SMILES found for ion: Pbs-QDs
# No SMILES found for ion: CMB
# No SMILES found for ion: TAE
# No SMILES found for ion: Spiro-PT-OMeTAD
# No SMILES found for ion: TSHBC-CF3
# No SMILES found for ion: PAH 2
# No SMILES found for ion: DOR3T-TBDT
# No SMILES found for ion: dly-2
# No SMILES found for ion: PSS
# No SMILES found for ion: DBTMT
# No SMILES found for ion: CaTiO3
# No SMILES found for ion: Mg-EA
# No SMILES found for ion: (BIM)
# No SMILES found for ion: pBDT-BODIPY
# No SMILES found for ion: PNP-BC
# No SMILES found for ion: NDI-H
# No SMILES found for ion: Li4Ti5O12
# No SMILES found for ion: WS-C60
# No SMILES found for ion: C60-NH2
# No SMILES found for ion: CdS-nw
# No SMILES found for ion: OMeTPA-TPA
# No SMILES found for ion: IZTO
# No SMILES found for ion: PH 1000
# No SMILES found for ion: 2,2′-[(4,5-Bis(1-octylnonyl)-dithieno[2,3-d:2′3′-d]thieno[3,2-b:4,5-b′]dipyrrole-2,7-diyl)bis(2,3-dihydrothieno[3,4-b][1,4]dioxin-5,5′-diyl)bis(methane-1-yl-1-ylidine)]dimalononitrile
# No SMILES found for ion: PTEBS
# No SMILES found for ion: AZO-c
# No SMILES found for ion: ZTO-mp
# No SMILES found for ion: PEN
# No SMILES found for ion: TTBCPE
# No SMILES found for ion: TPI-4MEO
# No SMILES found for ion: TPA-AZO
# No SMILES found for ion: TBC-1
# No SMILES found for ion: pBBTa‐BDT1
# No SMILES found for ion: EMIM-PF6
# No SMILES found for ion: SGT-404
# No SMILES found for ion: Fullerenol
# No SMILES found for ion: TPA-NPA-TPA
# No SMILES found for ion: BL40
# No SMILES found for ion: PBDTTT-C
# No SMILES found for ion: PC61BTh
# No SMILES found for ion: T(EDOT-TPA)2
# No SMILES found for ion: SiO2-mp
# No SMILES found for ion: (DAT)
# No SMILES found for ion: CuPc-OBu
# No SMILES found for ion: NDI-ID
# No SMILES found for ion: PFS-FTEG
# No SMILES found for ion: PTZ-TPA
# No SMILES found for ion: BTTI-C12
# No SMILES found for ion: MFGO
# No SMILES found for ion: P(NDI2DT-T2)
# No SMILES found for ion: PCPD2FBT:BCF
# No SMILES found for ion: (Cl-PEA)
# No SMILES found for ion: X60(TFSI)2
# No SMILES found for ion: MBA-SAM
# No SMILES found for ion: Z7@MWCNTs
# No SMILES found for ion: PMMA
# No SMILES found for ion: PB2T-O
# No SMILES found for ion: TTA
# No SMILES found for ion: HOOC-Ph-SH
# No SMILES found for ion: BTTI-C6
# No SMILES found for ion: C13-FAS
# No SMILES found for ion: (OctPhO)8ZnPc2
# No SMILES found for ion: TB4-ZnPc
# No SMILES found for ion: TiO2-helices
# No SMILES found for ion: 3, 4, 5- trimethoxybenzoic acid
# No SMILES found for ion: PCMB-60:BCP
# No SMILES found for ion: Bp-OMe
# No SMILES found for ion: S,N-Heteroacene 2
# No SMILES found for ion: TCP-OC8
# No SMILES found for ion: NAMF-Br
# No SMILES found for ion: Triazine-Ph-OMeTPA
# No SMILES found for ion: NDI-PhE
# No SMILES found for ion: F-R-COOK
# No SMILES found for ion: Azomethine
# No SMILES found for ion: (Ada)
# No SMILES found for ion: X-DVTPD
# No SMILES found for ion: pTPA-DBTP
# No SMILES found for ion: Co0.939Cu0.061O
# No SMILES found for ion: ICBA
# No SMILES found for ion: PMAA
# No SMILES found for ion: Polymer1
# No SMILES found for ion: PCBM-60-np
# No SMILES found for ion: quart-p-phenylene1
# No SMILES found for ion: DM
# No SMILES found for ion: Mix-DMEC70
# No SMILES found for ion: DMFA-FA
# No SMILES found for ion: TPASB
# No SMILES found for ion: (BzDA)
# No SMILES found for ion: asy-PBTBDT
# No SMILES found for ion: CdS-np
# No SMILES found for ion: PEDOT:PSS
# No SMILES found for ion: JTCA
# No SMILES found for ion: graphite nanofibers
# No SMILES found for ion: 1F-SAM
# No SMILES found for ion: Graphene oxide
# No SMILES found for ion: ZnO@rQD-np
# No SMILES found for ion: 5,5',5''-(5,5',5''-(nitrilotris(benzene-4,1-diyl))tris(furan-5,2-diyl))tris(2-octylisoindoline-1,3-dione)
# No SMILES found for ion: 1‐adamantylamine hydrochloride
# No SMILES found for ion: FPDI
# No SMILES found for ion: DBC-OMeDPA
# No SMILES found for ion: TbT-3
# No SMILES found for ion: AgInS2-QDs
# No SMILES found for ion: NiO-c
# No SMILES found for ion: M106
# No SMILES found for ion: (F3EA)
# No SMILES found for ion: PPyra-XA
# No SMILES found for ion: TaTm:F6-TCNNQ
# No SMILES found for ion: IDTCN
# No SMILES found for ion: M111
# No SMILES found for ion: ATT-OHex
# No SMILES found for ion: Fe2O3
# No SMILES found for ion: BChl-2
# No SMILES found for ion: ZnSO4-c
# No SMILES found for ion: Black phosphorous QDs
# No SMILES found for ion: M103
# No SMILES found for ion: FA
# No SMILES found for ion: 3,6-PCzTPA
# No SMILES found for ion: C60-5e
# No SMILES found for ion: 4,4'-(1,3,4-Oxadiazole-2,5-diyl)bis(N,N-bis(4-methoxyphenyl)aniline)
# No SMILES found for ion: PANI:PSS
# No SMILES found for ion: PDI-Br
# No SMILES found for ion: ZIF-8-40
# No SMILES found for ion: CsOAc
# No SMILES found for ion: BL08
# No SMILES found for ion: Polyacrylonitrile-grafted rGO
# No SMILES found for ion: FTA1
# No SMILES found for ion: 0.03
# No SMILES found for ion: GaIn
# No SMILES found for ion: S:DIB
# No SMILES found for ion: Porphyrin-H2
# No SMILES found for ion: IPA
# No SMILES found for ion: PVA
# No SMILES found for ion: MoOx
# No SMILES found for ion: Hexamethyl-substituted subphthalocyanine
# No SMILES found for ion: PBDB-T:ITIC
# No SMILES found for ion: ZnSO
# No SMILES found for ion: FrGO
# No SMILES found for ion: TT-3,6-TPA
# No SMILES found for ion: (PMA)
# No SMILES found for ion: Bi2S3
# No SMILES found for ion: M1
# No SMILES found for ion: PTAA-1F
# No SMILES found for ion: Py-OMe
# No SMILES found for ion: HMDI
# No SMILES found for ion: (RuCp*mes)2
# No SMILES found for ion: H-Z1
# No SMILES found for ion: TPE-4DPA
# No SMILES found for ion: WO3-nw
# No SMILES found for ion: Heparin-Na
# No SMILES found for ion: PTTI-1
# No SMILES found for ion: V1207
# No SMILES found for ion: CuPcNO2-OMFPh
# No SMILES found for ion: Transparent Conductive Adhesive
# No SMILES found for ion: IDTT2FPDI
# No SMILES found for ion: oxo-Graphene
# No SMILES found for ion: nTi-MOF
# No SMILES found for ion: 2H-MoS2
# No SMILES found for ion: di-TPA
# No SMILES found for ion: P3CT-N
# No SMILES found for ion: TQ1d
# No SMILES found for ion: tetra{4-[N,N-(4,4'-dimethoxydiphenylamino)]phenyl}ethene
# No SMILES found for ion: BL07
# No SMILES found for ion: DMC
# No SMILES found for ion: TiP2-c
# No SMILES found for ion: TPA1C
# No SMILES found for ion: t-BPTI
# No SMILES found for ion: Dex-CB-MA
# No SMILES found for ion: FDA
# No SMILES found for ion: ZnChl-2
# No SMILES found for ion: ZnPcNO2-OBFPh
# No SMILES found for ion: MeOAc-Spiro-OMeTAD
# No SMILES found for ion: TiO2-nanoleaves
# No SMILES found for ion: TZ-2
# No SMILES found for ion: EDOT-MPH
# No SMILES found for ion: KR145
# No SMILES found for ion: (HAD)
# No SMILES found for ion: 2-(3,5-bis(5-(5-hexylthiophen-2-yl)thiophen-2-yl)thiophen-2-yl)-3,5-bis(5-(5-hexylthiophen-2-yl)thiophen-2-yl)thiophene
# No SMILES found for ion: C60-5b
# No SMILES found for ion: (BDA)
# No SMILES found for ion: bis-C61
# No SMILES found for ion: Ti-sheet
# No SMILES found for ion: Nb2O3
# No SMILES found for ion: 1a @ triphenylamine modified azobenzene dyes
# No SMILES found for ion: (MTEA)
# No SMILES found for ion: CuS-np
# No SMILES found for ion: ZPPHT
# No SMILES found for ion: PVK
# No SMILES found for ion: r-GO-NH
# No SMILES found for ion: pBTTz
# No SMILES found for ion: Li-TFSI
# No SMILES found for ion: (OctPhO)8CuPc1
# No SMILES found for ion: FA-CN
# No SMILES found for ion: FT73
# No SMILES found for ion: ETPM
# No SMILES found for ion: PFPDI
# No SMILES found for ion: PEH-2
# No SMILES found for ion: Fullerene-SAM
# No SMILES found for ion: 4-F-br-4C
# No SMILES found for ion: Tea Catachinrich biomolecules
# No SMILES found for ion: PEA2PBI4
# No SMILES found for ion: Cr2O3:Cr
# No SMILES found for ion: IT4F
# No SMILES found for ion: BTPA-4
# No SMILES found for ion: BaSnO3
# No SMILES found for ion: BA-SAM
# No SMILES found for ion: V885
# No SMILES found for ion: BTBDT
# No SMILES found for ion: KR374
# No SMILES found for ion: CZTS-np
# No SMILES found for ion: CT4
# No SMILES found for ion: pm-TPE-4DPA
# No SMILES found for ion: B-DIPBI
# No SMILES found for ion: Z29
# No SMILES found for ion: 5,5',5''-(5,5',5''-(nitrilotris(benzene-4,1-diyl))tris(furan-5,2-diyl))tris(2-octylisoindoline-1,3-dione
# No SMILES found for ion: Ni-acetate
# No SMILES found for ion: F4TCNQ
# No SMILES found for ion: Poly(N-vinylcarbazole)
# No SMILES found for ion: KY7F22-np
# No SMILES found for ion: 2H-TaS2
# ...
# No SMILES found for ion: Spiro-MeOTAD-F
# No SMILES found for ion: a-PTCDI
# No SMILES found for ion: TiO2-hollow spheres
# No SMILES found for ion: P(NDI2OD-T2)
# No SMILES found for ion: KTM3
# No SMILES found for ion: benzo[1,2b:4,5b′]-dithiophene
# No SMILES found for ion: FH-0
# No SMILES found for ion: ZnChl
# No SMILES found for ion: M:ON
# No SMILES found for ion: 3,4-spiro
# No SMILES found for ion: Co0.695Cu0.305O
# No SMILES found for ion: HFB-OMeDPA
# No SMILES found for ion: Zn:CuGaO2
# No SMILES found for ion: BTTP-CN
# No SMILES found for ion: Spiro-OiPrTAD
# No SMILES found for ion: 2PDI-3S
# No SMILES found for ion: Carbozole @ S12
# No SMILES found for ion: PTEG
# No SMILES found for ion: HATNAS3C7-Cs
# No SMILES found for ion: CsCuBr3-QDs
# No SMILES found for ion: XSln1453
# No SMILES found for ion: PbPc
# No SMILES found for ion: PZn-FTPA
# No SMILES found for ion: 3,6-2,7-PCzTPA
# No SMILES found for ion: Poly[4,8-bis(2-(4-(2-ethylhexyloxy)3-fluorophenyl)-5-thienyl)benzo[1,2-b:4,5-b'] dithiophenealt-1,3-bis(4-octylthien-2-yl)-5-(2-ethylhexyl)thieno[3,4-c]pyrrole-4,6-dione
# No SMILES found for ion: 4PA-SAM
# No SMILES found for ion: 2-OMe-SAM
# No SMILES found for ion: PTMA-BP
# No SMILES found for ion: DBP
# No SMILES found for ion: (3AMP)
# No SMILES found for ion: PANI-PAMSA
# No SMILES found for ion: 2,4-spiro
# No SMILES found for ion: KH570
# No SMILES found for ion: PdMe2Pc
# No SMILES found for ion: LCS01
# No SMILES found for ion: 3,6-triphenylamine-carbazole
# No SMILES found for ion: PhCz-4MeOTPA
# No SMILES found for ion: DWCNTs
# No SMILES found for ion: Sr2CeO4:Eu
# No SMILES found for ion: NDI-TriSe
# No SMILES found for ion: SU-8
# No SMILES found for ion: TPP-SMeTAD
# No SMILES found for ion: Me-QTPA
# No SMILES found for ion: ICBM
# No SMILES found for ion: Cu0.8Cr0.2O2
# No SMILES found for ion: PEA
# No SMILES found for ion: OMeTPA-FA
# No SMILES found for ion: Polystyrene-ns
# No SMILES found for ion: H3PW12O4
# No SMILES found for ion: DTS(IIThThHEX)2
# No SMILES found for ion: DA-PEDOT:PSS
# No SMILES found for ion: IDTT-TPA
# No SMILES found for ion: SnO2@TiO2-np
# No SMILES found for ion: TPA-3CN
# No SMILES found for ion: PI
# No SMILES found for ion: TiO2-c
# No SMILES found for ion: MgO
# No SMILES found for ion: FT55
# No SMILES found for ion: NiMgLiO
# No SMILES found for ion: Cu-ribbon
# No SMILES found for ion: Polyethylimine
# No SMILES found for ion: N1,N3,N5-tris(4-n-butylphenyl)-N1,N3,N5-triphenylbenzene-1,3,5-triamine
# No SMILES found for ion: TTPA-DSQT
# No SMILES found for ion: BPB-M
# No SMILES found for ion: PDI-DA
# No SMILES found for ion: IBF-Ep
# No SMILES found for ion: PEDOT:P(SS-co-TFPMA)
# No SMILES found for ion: F-C60
# No SMILES found for ion: DTh101
# No SMILES found for ion: EtheneTTPA
# No SMILES found for ion: TPE-DPP8
# No SMILES found for ion: M107
# No SMILES found for ion: Spiro-OBuTAD
# No SMILES found for ion: [BMPA-EDOT]3-TPA
# No SMILES found for ion: Mg(AcO)2
# No SMILES found for ion: Asy-PBTBDT
# No SMILES found for ion: PyThTPA
# No SMILES found for ion: N2200
# No SMILES found for ion: Ag-grid
# No SMILES found for ion: C3-CBL
# No SMILES found for ion: DBFMT
# No SMILES found for ion: Poly[4,8-bis(2-(4-(2-ethylhexyloxy)3,5-fluorophenyl)-5-thienyl)benzo[1,2-b:4,5-b']dithiophenealt-1,3-bis(4-octylthien-2-yl)-5-(2-ethylhexyl)thieno[3,4-c]pyrrole-4,6-dione
# No SMILES found for ion: D-C60
# No SMILES found for ion: (4AMP)
# No SMILES found for ion: FPyBr
# No SMILES found for ion: V997
# No SMILES found for ion: Bacteriorhodopsin
# No SMILES found for ion: KH560
# No SMILES found for ion: TEASCN
# No SMILES found for ion: 2-F-br-4C
# No SMILES found for ion: PEAI
# No SMILES found for ion: SO10
# No SMILES found for ion: Florinated polymer
# No SMILES found for ion: Poly(9-vinylcarbazole)
# No SMILES found for ion: PrC60MA
# No SMILES found for ion: 1c @ triphenylamine modified azobenzene dyes
# No SMILES found for ion: Spiro-N
# No SMILES found for ion: 1b @ triphenylamine modified azobenzene dyes
# No SMILES found for ion: Zn:SnO2
# No SMILES found for ion: IDT6CN
# No SMILES found for ion: ZnPc-p-ZnPc 1
# No SMILES found for ion: O5H-OMeDPA
# No SMILES found for ion: Azu-Hex
# No SMILES found for ion: PCBM-derivative11
# No SMILES found for ion: tris-PCBOE
# No SMILES found for ion: PC61BEH
# No SMILES found for ion: PCBB-3N
# No SMILES found for ion: ITO:ATO
# No SMILES found for ion: POSS-SH
# No SMILES found for ion: CuPcNO2-OBFPh
# No SMILES found for ion: P3TAA
# No SMILES found for ion: CuFeO2-np
# No SMILES found for ion: MC-43
# No SMILES found for ion: PAA-PEG
# No SMILES found for ion: 1,2-Bis[3,6-(4,4`-dimethoxydiphenylamino)-9H-carbazol-9-methyl]benzene
# No SMILES found for ion: PTZ-1
# No SMILES found for ion: P1C1
# No SMILES found for ion: POZ10
# No SMILES found for ion: P1Z1
# No SMILES found for ion: CuSeCN
# No SMILES found for ion: Zn2SnO4-nw
# No SMILES found for ion: LD29
# No SMILES found for ion: P:ON
# No SMILES found for ion: BDT2FMeDPA
# No SMILES found for ion: Py-COF
# No SMILES found for ion: CuGaO2-c
# No SMILES found for ion: BaCoF4
# No SMILES found for ion: DCZ-OMeTPA
# No SMILES found for ion: DM1P
# No SMILES found for ion: PVCz-OMeDPD
# No SMILES found for ion: CS02
# No SMILES found for ion: BL25
# No SMILES found for ion: C60(OH)16
# No SMILES found for ion: Phosphor-QDs
# No SMILES found for ion: 4-(5-(5-(5-(5-(5-hexylthiophen-2-yl) thiophen-2-yl) thiophene-2-yl) thiazolo[5,4-d]thiazol-2-yl) thiophene2-yl)-N,N-diphenyl-benzenamine
# No SMILES found for ion: GeO2
# No SMILES found for ion: KH550
# No SMILES found for ion: YC06
# No SMILES found for ion: PDPPT-TT
# No SMILES found for ion: ZnLiO
# No SMILES found for ion: Meo-4PACz
# No SMILES found for ion: PST1
# No SMILES found for ion: PPN
# No SMILES found for ion: H-Tetra
# No SMILES found for ion: IEICO
# No SMILES found for ion: ITCPTC-Se
# No SMILES found for ion: PFN-P1
# No SMILES found for ion: Z35
# No SMILES found for ion: RCP-BTT
# No SMILES found for ion: DFBT(DTS-FBTTh2)2
# No SMILES found for ion: Dispiro-OMeTAD
# No SMILES found for ion: BTTI-C8
# No SMILES found for ion: M116
# No SMILES found for ion: C60SB:TBAI
# No SMILES found for ion: Graphdiyne-QDs
# No SMILES found for ion: ST1 (4-(4-(bis(4-(4-(dibutylamino)styryl)phenyl)amino)styryl)-N,N-dibutylaniline)
# No SMILES found for ion: (2Z,2'Z)-2,2'-(((2,4-dimethylphenyl) azanediyl) bis([1,1'-biphenyl]-4',4-diyl)) bis(3-(4-(diphenylamino) phenyl) acrylonitrile
# No SMILES found for ion: TPDI
# No SMILES found for ion: EH44
# No SMILES found for ion: J61-ITIC
# No SMILES found for ion: mGO
# No SMILES found for ion: Spiro-E
# No SMILES found for ion: PFS-FC
# No SMILES found for ion: CYOP
# No SMILES found for ion: PYPH
# No SMILES found for ion: 1‐benzyl‐3‐methylimidazolium chloride
# No SMILES found for ion: mp-SFX-3PA
# No SMILES found for ion: PH1000
# No SMILES found for ion: H3
# No SMILES found for ion: 3-OMe-SAM
# No SMILES found for ion: N,N-bis-[7-(4,4′-dimethoxydiphenylamine)-9- (bis(methylsulfanyl)methylene)fluoren-2-yl]-4-methoxyaniline
# No SMILES found for ion: Poly(3-bromothiophene)
# No SMILES found for ion: PDI-V
# No SMILES found for ion: 5,7-disubstituted azulene
# No SMILES found for ion: Z3
# No SMILES found for ion: M7-TFSI
# No SMILES found for ion: C102
# No SMILES found for ion: ATT-ODec
# No SMILES found for ion: CrOx
# No SMILES found for ion: TB(MA)
# No SMILES found for ion: SrTiO3:TiO2-mp
# No SMILES found for ion: PTPADCF3FSONa
# No SMILES found for ion: (1.3-Pr(NH3)2)
# No SMILES found for ion: ZnO-mp
# No SMILES found for ion: IDT-TPA
# No SMILES found for ion: (iPA)
# No SMILES found for ion: TiO2-nanosphere
# No SMILES found for ion: BDT0FMeDPA
# No SMILES found for ion: HA
# No SMILES found for ion: PBDT(2H)T
# No SMILES found for ion: Cu0.33Cr0.67O2
# No SMILES found for ion: PII2T8T
# No SMILES found for ion: CdSe-QDs
# No SMILES found for ion: (CHMA)
# No SMILES found for ion: EVA
# No SMILES found for ion: YVO4:Eu:Bi-np
# No SMILES found for ion: PCTDI
# No SMILES found for ion: Z28
# No SMILES found for ion: NbOH5
# No SMILES found for ion: (PEI)
# No SMILES found for ion: Zr(acac)4
# No SMILES found for ion: Ph-TPA-8A
# No SMILES found for ion: EFGnPs-H
# No SMILES found for ion: PDPPDBTE
# No SMILES found for ion: TPA-MeOPh
# No SMILES found for ion: HTM-P1
# No SMILES found for ion: NDIF2
# No SMILES found for ion: PEI-HI
# No SMILES found for ion: Mercaptoethylamine chlorate
# No SMILES found for ion: mm-SFX-2PA
# No SMILES found for ion: SrTiO3-np
# No SMILES found for ion: Spiro-OEtTAD
# No SMILES found for ion: CuPcNO2-OPh
# No SMILES found for ion: CZTPA-1
# No SMILES found for ion: mm-SFX-3PA
# No SMILES found for ion: PDI-T
# No SMILES found for ion: Ome-DPA-CuPc
# No SMILES found for ion: c-TCTA
# No SMILES found for ion: Z2
# No SMILES found for ion: PA-SAM
# No SMILES found for ion: TCl-PDI
# No SMILES found for ion: Silk
# No SMILES found for ion: OMETPA-BDT
# No SMILES found for ion: styryl-functionalized GO
# No SMILES found for ion: PFN-2TNDI
# No SMILES found for ion: Zn2SnO4-mp
# No SMILES found for ion: Cu@CuI-nw
# No SMILES found for ion: 3,6-cbz-EDOT
# No SMILES found for ion: HTM-3
# No SMILES found for ion: BDT:TT
# No SMILES found for ion: (2Z,2′Z)-3,3′-(5,5′-(2,7-dioctyl-1,3,6,8-tetraoxo-1,2,3,6,7,8-hexahydrobenzo[lmn][3,8] phenanthroline-4,9-diyl)bis(thiophene-5,2-diyl))bis(2-(3,5-bis (trifluoroomethyl)phenyl) acrylonitrile)
# No SMILES found for ion: TPDCN
# No SMILES found for ion: CuCrO2
# No SMILES found for ion: OA
# No SMILES found for ion: QCAPZ
# No SMILES found for ion: IrTiOx-c
# No SMILES found for ion: PTEG-1
# No SMILES found for ion: CzPAF‐SBF
# No SMILES found for ion: CeOx
# No SMILES found for ion: pi-PFE3
# No SMILES found for ion: Car-ETTA
# No SMILES found for ion: H-3,4
# No SMILES found for ion: PNDI20D-TT
# No SMILES found for ion: CuOx
# No SMILES found for ion: TPB(2-TPTZ)
# No SMILES found for ion: Al-np
# No SMILES found for ion: ITCPTC-Th
# No SMILES found for ion: P-TPD
# No SMILES found for ion: PCBM-60-DPM-OE
# No SMILES found for ion: DPA-ANT-DPA
# No SMILES found for ion: NOA88
# No SMILES found for ion: GO-nanoribbons
# No SMILES found for ion: CsSnBr2I-QDs
# No SMILES found for ion: (RhCp*Cp)2
# No SMILES found for ion: SFT-TPAM
# No SMILES found for ion: MSA-PEDOT:PSS
# No SMILES found for ion: EDOT-OMeTPA
# No SMILES found for ion: PASQ-IDT
# No SMILES found for ion: C-PCBOD
# No SMILES found for ion: PSS-g-PANI
# No SMILES found for ion: NiPc-Cou
# No SMILES found for ion: CZTSe-QDs
# No SMILES found for ion: [Fe(bpyPY4)](OTf)2.5
# No SMILES found for ion: WO3-nw@PEDOT
# No SMILES found for ion: Ti3C2Tx
# No SMILES found for ion: Sn2O3-ns
# No SMILES found for ion: MAI
# No SMILES found for ion: Paper
# No SMILES found for ion: Alkoxy-PTEG
# No SMILES found for ion: CMB-vTA
# No SMILES found for ion: (F-PEA)
# No SMILES found for ion: Y4
# No SMILES found for ion: PDPT
# No SMILES found for ion: Polyacrylonitrile
# No SMILES found for ion: AlNi-grid
# No SMILES found for ion: P1-2
# No SMILES found for ion: PCBSD
# No SMILES found for ion: C60-np
# No SMILES found for ion: C60-lactone
# No SMILES found for ion: NiMgLiO-c
# No SMILES found for ion: PVDF-HFP
# No SMILES found for ion: DEPT-SC
# No SMILES found for ion: (4ApyH)
# No SMILES found for ion: F101
# No SMILES found for ion: C60-5g
# No SMILES found for ion: C-PCBSD
# No SMILES found for ion: SiO2-c
# No SMILES found for ion: CPTA-E
# No SMILES found for ion: CuMe2Pc
# No SMILES found for ion: Co3O4
# No SMILES found for ion: Ph-TPA-6A
# No SMILES found for ion: CuZnS
# No SMILES found for ion: CdSe-tetrapod
# No SMILES found for ion: PDQT
# No SMILES found for ion: STHNP
# No SMILES found for ion: NDI-Se
# No SMILES found for ion: Tetrakis(4-methoxyphenyl)spiro[cyclopenta[1,2-b:5,4-b']dipyridine-5,9'-fluorene]-2',7'-diamine
# No SMILES found for ion: H111
# No SMILES found for ion: BenMeIM-Cl
# No SMILES found for ion: G2
# No SMILES found for ion: CA-Br
# No SMILES found for ion: Sb2S3
# No SMILES found for ion: H-2,3
# No SMILES found for ion: 1,2-ethanedithiol (5 mM)
# No SMILES found for ion: Al2O3-np
# No SMILES found for ion: WT3
# No SMILES found for ion: AgAl-np
# No SMILES found for ion: Au-nanobipyramide
# No SMILES found for ion: TiS2-np
# No SMILES found for ion: S9
# No SMILES found for ion: CoCr-mp
# No SMILES found for ion: ZnBu4Pc
# No SMILES found for ion: PBDTT-SeDPP
# Number of ions in the error message that are NOT present in the dataset: 690
# Ions not found in the dataset: ['2PDI-4S', 'IDF-SFXPh', 'diPDI', 'WPF‐6‐oxy‐F', 'Poly(2-ethyl-2-oxazoline)', '(TEA)', 'CSCNT', 'pi-PFE4', 'H2-Chl', 'Ta2O5', 'Willow glas', 'MgF2', 'PASP', 'GFRHybrimer', 'Au-grid', 'HDAC', 'DAHI', 'Au@TiO2-np', 'BAFB', 'Me4NI', 'HS-Ph-NO2', 'TiO2-nanoflowers', 'PC61BPy', 'PrCMA', 'bis-C70', '(4AMPY)', 'Sn2O3-qd', 'C12-silane-SAM', 'Cyptop', 'SAM1', '(ThMA)', 'C60:PhIm', 'PhCOOH', 'YVO4:Eu', 'ZnS-QDs', 'PTFTS', 'ITO-nw', 'In2O3:H', 'TiO2-nanowalls', 'HCLaminate', '4-aminobenzoic acid-SAM', 'Carbon black@5:1', 'I-Ph-PA_C60-C6-PA', 'HOOC-C11H22-SH', 'ZrAcAc', 'Polycarbonate', 'Ba0.9Sr0.1SnO3-np', 'TN', 'ZnO-nanodisks', 'CON-16', 'BZnTPP', 'NDI', '4-dimethoxybenzoic acid', '2,6-Py', 'ZnO-nanowells', 'PTCDI', 'NaYF4-np', 'TPE-DPP6', 'PS-b-PEO', 'TCPI', 'Ag-nanocubes', 'Au@SnO2-np', 'Bis-FITG', 'DEA', 'Zeocoat', 'PEIA', 'CdSe-QD', 'ZIF-8-10', 'HOFP', 'AV-Carbon', 'Dompamin-SAM', 'CuO-nw', 'TFSA-Graphene', 'OEABS', 'PNVT-8', '3-aminopropanioc acid-SAM', 'Me4NBr', 'DI', 'SiW11O39-POM', 'ZIF-8-20', 'TDPP-CN4', 'ZnO-nanofibers', 'Carbo-QDs', 'rGO-flakes', '(HEA)', 'Zr(Acac)', 'Lignosulfonate', 'Cu-tape', 'CON-10', 'p-(F)-PO-TAZ', 'C60-MPy', '(NMA)', 'CoCr', 'NMBI', 'CdSO', 'Cellophane', 's-Bphen', '(DPA)', 'Sb-Carbon-nw', '(Ace)', '(H-PEA)', 'Black phosphorous 2D', 'Cs-oleate', 'IDF-DiDPA', 'TPI-6MEO', 'SnO', 'MUTAB-SAM', 'Ppz', 'Mono-PCBOE', 'TPE-PDI4', 'CZTS0.75Se0.25', 'OCA', 'FNCA', 'TOPD', 'resist', 'Poly(TA)', 'NaYF4:Yb:Tm-np', 'PhIm', 'LT-TiO2:Cl', 'NH2-POSS', 'PO-TAZ', 'SnS-np', 'ITO-HMDS Scaffold', 'COi8DFIC', 'C12H10B2O4', 'ZrO2-c', '(4FPEA)', 'DA', 'PES', '1,2-ethanedithiol (10 mM)', 'PPDI-F3N', 'Ps', 'FBT-TH4', 'HS-Ph-CN', 'MoO3 ∣ Au ∣ Ag ∣ MoO3', 'MoOx-np', 'BU', 'MCA', 'Ag-mesh:PH1000', 'ZnSnO4-c', 'N-[3-(Trimethoxysilyl)propyl]ethylenediamine-SAM', 'TiO2-nanofibres', 'CSOE', 'Silica gel electrolyte', 'Cu-BHT', '5-AVA', 'Zn2Ti3O8-mp', '(5-AVAI)', 'HS-Ph-OCH3', 'IT-M', 'm-PYBrZnPor', 'Nb2O5-mp', 'NaPTH', 'MoS2-QDs', 'D149', '2-PA-SAM', 'AL2O3-c', 'Poly-N-vinylcarbazole', 'PTZ-2', 'BaTiO3-mp', 'HS-Ph-SCH3', 'FA-PDI2', 'FSIP', 'C60-HPy', '(TBA)', 'CZTS0.25Se0.75', 'Zn(acac)', 'PFN-Ox', 'BaTiO3', '(SCN)', 'PCBB-2CN-2C8', 'Sb2O3-np', 'Rodhamine 101', 'PCBB-3N-3I', 'Phen-NaDPO:Sn(SCN)2', 'CBA-SAM', 'T2CA', 'ZnS-np', 'Ta2O3', 'Polyethylene glycol', 'IT4H', 'Foil', 'BSO-mp', 'DTPC8-ThTPA', '(DTYM-NDI-DTYA)2', '(EDA)', 'IDT6CN-4F', 'PBDTTT-E-T', 'C60-5c', 'ITCP-M', 'pi-PFE2', 'rGO:TiO2-nanofibrse', '2-HI-PVK', '3,4-b′]dithiophene', 'TiO2-nanobeads', 'Au-nw', 'Bis-FIMG', 'C5-NCMA', 'ZnMgO-c', 'CdZnSeS-QDs', 'MnO3', 'C60-BCT-Au-NP', 'Nanopaper', 'S-acetylthiocholine chlorde', 'PD-10-DTTE-7', 'd-PCBM-60', 'ABA-SAM', 'TEAI', 'PPDIN6', 'BACl', 'Au@TiO2-nw', 'Si-QDs', '(3AMPY)', '(IEA)', 'SLG-HAMC-patterned', 'Cs4SnO4', 'TiO2-IO', '(mF1PEA)', 'PEDOT:PSSl', 'AuAg', 'SFX-PDI4', 'AQ310', 'Au@Ag', 'AgAu-np', "Fused-F (Tris[[4-[3,3'-dihexylsilylene-2,2'-bithiophene]-7-[5′′-n-hexyl-(2,2′", 'Si-nw', 'Si-np', 'ZnSO4-mp', 'TEACl', 'Br-BPA-SAM', 'AUH', '1‐adamantylamine', '(pF1PEA)', '2PDI-0S', 'ZnCdS', 'b-CNF', 'Ag@TiO2-np', 'A-PDTON', 'C60-ETA', 'Aa', 'CuInS', 'beta-Alanine-SAM', 'PrC60MAI', 'bis-PCBOE', 'NaYF4', 'DMEC-70', 'Plastic foam', 'SrTiO3-c', 'ACO-c', 'Ce2O-mp', 'C60-BPy', 'ICTA', '2PDI-2S', 'SiO2-hollow', 'TDTP', 'CuxO', 'Organosilicate', 'ICPA', 'Au-wire', 'pi-PFE1', 'Ca(acac)2', '(CIEA)', 'SLNOA63', 'Na3C6H5O7', 'Zr(AcAc)', 'TmTyPB', 'C60-BCT', 'Regenerated cellulose film', 'cyclopenta[2,1-b', 'TFDIB', 'SnZnO', 'Au@SiO2-np', 'CH3O-PEIA', 'DMEC-60', 'Me2N-DATPA', 'Nafion', 'ZrO2-mp', 'TPE-DPP16', '4-DMABA', 'Au@SnO2-nw', 'NO2-PEIA', 'Ag@TiO2-nw', 'AgZn', 'CH3-PEIA', 'UiO-66', 'C60-5d', 'Al3O3-mp', 'N749', '(PF6)', '1,2-ethanedithiol (15 mM)', 'Cu-grid', 'Ba0.8Sr0.2SnO3-np', 'ADAHCl', '2F-SAM', 'CsPbI3-QD', '(PBA)', 'NBA-SAM', 'ZnSnO4-mp', 'PPDIDTT', 'PABA-SAM', 'PEI (CAS # 61128-46-9)', 'CuInS2', 'MPTMS-SMA', 'TZ-1', 'nc-TiO2', '(4AMP)I2', 'DMAPA-C60', 'ICBA-tran3', 'ZnOS', 'CdSe-Qd', 'PPNBr', 'NPC60 O ...

# %%
target_ion = 'VB'
columns_with_ion = df.columns[df.isin([target_ion]).any()].tolist()
print(f"The ion '{target_ion}' is found in: {columns_with_ion}")
# Out:
# The ion 'VB' is found in: []

# %%
## version 2

import pandas as pd
import pubchempy as pcp
import json
import time
from concurrent.futures import ThreadPoolExecutor
from collections import defaultdict

# Define columns of interest
psc_stack_columns = [
    'Perovskite_composition_a_ions', 'Perovskite_composition_b_ions', 
    'Perovskite_composition_c_ions', 'Substrate_stack_sequence', 
    'ETL_stack_sequence', 'HTL_stack_sequence', 'Backcontact_stack_sequence'
]

# Initialize cache
smiles_cache = {}

# Try to load the cache from a file if it exists
cache_file = 'smiles_cache.json'
try:
    with open(cache_file, 'r') as f:
        smiles_cache = json.load(f)
        print("Loaded smiles cache from file.")
except FileNotFoundError:
    print("Cache file not found. Fetching SMILES from PubChem.")

# Function to fetch SMILES from PubChem with retries
def fetch_smiles_from_pubchem(ion, retries=3, delay=2):
    """
    Fetch SMILES for a given ion from PubChem, with retries in case of server issues.
    """
    try:
        compound = pcp.get_compounds(ion, 'name')
        if compound and compound[0].isomeric_smiles:
            return compound[0].isomeric_smiles
        else:
            return None  # No SMILES found
    except Exception as e:
        if retries > 0:
            print(f"Error fetching SMILES for ion '{ion}': {e}. Retrying...")
            time.sleep(delay)  # Wait before retrying
            return fetch_smiles_from_pubchem(ion, retries-1, delay)
        else:
            print(f"Error fetching SMILES for ion '{ion}': {e}. Skipping.")
            return None

# Function to fetch SMILES in batch for a list of ions
def batch_fetch_smiles(ions):
    """
    Populate the smiles_cache with SMILES for each ion using multiple threads.
    """
    with ThreadPoolExecutor(max_workers=8) as executor:
        results = list(executor.map(fetch_smiles_from_pubchem, ions))
        for ion, smiles in zip(ions, results):
            if smiles:
                smiles_cache[ion] = smiles

# Function to convert Ion column to SMILES using the cache
def convert_to_smiles(ion_str):
    """
    Converts a string of ions into their SMILES representation.
    Handles multiple ions separated by ':' or '|'.
    """
    if pd.isna(ion_str):  # Handle missing values
        return None
    
    # Normalize delimiters to ':' and split the ions
    normalized_str = ion_str.replace('|', ':')
    ions = normalized_str.split(':')
    
    # Use the cache to fetch SMILES
    smiles_list = [smiles_cache.get(ion.strip()) for ion in ions if smiles_cache.get(ion.strip()) is not None]
    return '.'.join(smiles_list) if smiles_list else None

# Load dataset (replace with your actual file path)
df = pd.read_csv('initial_cleaned_data.csv')

# Step 1: Collect all unique ions from the dataset columns
all_ions = set()
for col in psc_stack_columns:
    if col in df.columns:  # Ensure the column exists in the dataset
        df[col].dropna().apply(lambda x: all_ions.update([ion.strip() for ion in x.replace('|', ':').split(':')]))

# Step 2: Fetch SMILES for all unique ions
batch_fetch_smiles(all_ions)

# Step 3: Apply the conversion to each specified column
for col in psc_stack_columns:
    if col in df.columns:  # Ensure the column exists
        smiles_col = col + '_SMILES'
        df[smiles_col] = df[col].apply(convert_to_smiles)

# Save the updated dataframe to a new CSV file
output_file_path = 'cleaned_data_with_smiles.csv'
df.to_csv(output_file_path, index=False)

# # Save the smiles cache to a file for future use
# with open(cache_file, 'w') as f:
#     json.dump(smiles_cache, f)
#     print("Smiles cache saved to file.")
# Out:
# Loaded smiles cache from file.
# C:\Users\c\AppData\Local\Temp\ipykernel_22404\275532749.py:78: DtypeWarning: Columns (15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('initial_cleaned_data.csv')
# Error fetching SMILES for ion 'PDI': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Ti': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'WPF‐6‐oxy‐F': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'BA; FA': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Nb2O5': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion '2FBTA-2': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Ta2O5': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'H2-Chl': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion '3,8,13-tris[2,2-bis(4-methoxyphenyl)ethenyl]-5,10,15-triethyl-10,15-dihydro-5H-indolo-[3,2-a': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'M109': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'PDMS': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Fullerene @ F3': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'PtMePy': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'PdMePy': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'BTPA-5': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'V859': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'C60; PEIE': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'PF8-TAA': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'SDTCz2F': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'SnO2-nt': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Li4SiW12O40': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'HTM-M1': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'TiO2; WOx': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Spiro-MeOTAD; X60': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Ph-TPA-2A': 'PUGREST.ServerBusy'. Retrying...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 87
#      84         df[col].dropna().apply(lambda x: all_ions.update([ion.strip() for ion in x.replace('|', ':').split(':')]))
#      86 # Step 2: Fetch SMILES for all unique ions
# ---> 87 batch_fetch_smiles(all_ions)
#      89 # Step 3: Apply the conversion to each specified column
#      90 for col in psc_stack_columns:
#
# Cell In[2], line 55, in batch_fetch_smiles(ions)
#      51 """
#      52 Populate the smiles_cache with SMILES for each ion using multiple threads.
#      53 """
#      54 with ThreadPoolExecutor(max_workers=8) as executor:
# ---> 55     results = list(executor.map(fetch_smiles_from_pubchem, ions))
#      56     for ion, smiles in zip(ions, results):
#      57         if smiles:
#
# File c:\Users\c\miniconda3\envs\test-env\Lib\concurrent\futures\_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File c:\Users\c\miniconda3\envs\test-env\Lib\concurrent\futures\_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File c:\Users\c\miniconda3\envs\test-env\Lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File c:\Users\c\miniconda3\envs\test-env\Lib\threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
## check 

import pubchempy as pcp

# Define the ions you want to check
ions = ['Na+', 'Cl-']

# Function to fetch SMILES for a given ion
def fetch_smiles_for_ions(ions):
    for ion in ions:
        try:
            # Query PubChem for the ion by name
            compound = pcp.get_compounds(ion, 'name')
            if compound:
                print(f"SMILES for {ion}: {compound[0].canonical_smiles}")
            else:
                print(f"No SMILES found for ion: {ion}")
        except Exception as e:
            print(f"Error fetching SMILES for {ion}: {e}")

# Test the function with two known ions
fetch_smiles_for_ions(ions)
# Out:
# SMILES for Na+: [Na+]
# SMILES for Cl-: [Cl-]

# %% [markdown]
# 2. Combining the 3 perovskite ion SMILES columns into one

# %%
import pandas as pd
import pubchempy as pcp
import json
from concurrent.futures import ThreadPoolExecutor
import time
import pandas as pd
import pubchempy as pcp
import json
from concurrent.futures import ThreadPoolExecutor

df = pd.read_csv(r'cleaned_data_with_smiles.csv')

# Initialize an empty cache dictionary or load from a cache file
smiles_cache = {}

# Try to load the cache from a file if it exists
cache_file = 'smiles_cache.json'
try:
    with open(cache_file, 'r') as f:
        smiles_cache = json.load(f)
        print("Loaded smiles cache from file.")
except FileNotFoundError:
    print("Cache file not found. Fetching SMILES from PubChem.")

# Function to fetch SMILES from PubChem with retries
def fetch_smiles_from_pubchem(ion, retries=3, delay=2):
    """
    Fetch SMILES for a given ion from PubChem, with retries in case of server issues.
    """
    try:
        compound = pcp.get_compounds(ion, 'name')
        if compound and compound[0].isomeric_smiles:
            return compound[0].isomeric_smiles
        else:
            return None  # No SMILES found
    except Exception as e:
        if retries > 0:
            print(f"Error fetching SMILES for ion '{ion}': {e}. Retrying...")
            time.sleep(delay)  # Wait before retrying
            return fetch_smiles_from_pubchem(ion, retries-1, delay)
        else:
            print(f"Error fetching SMILES for ion '{ion}': {e}. Skipping.")
            return None

# Function to fetch SMILES in batch for a list of ions
def batch_fetch_smiles(ions):
    """
    Populate the smiles_cache with SMILES for each ion using multiple threads.
    """
    with ThreadPoolExecutor(max_workers=8) as executor:
        results = list(executor.map(fetch_smiles_from_pubchem, ions))
        for ion, smiles in zip(ions, results):
            if smiles:
                smiles_cache[ion] = smiles

# Function to convert Ion column to SMILES using the cache
def convert_to_smiles(ion_str):
    """
    Converts a string of ions into their SMILES representation.
    Handles multiple ions separated by ':' or '|'.
    """
    if pd.isna(ion_str):  # Handle missing values
        return None
    
    # Normalize delimiters to ':' and split the ions
    normalized_str = ion_str.replace('|', ':')
    ions = normalized_str.split(':')
    
    # Use the cache to fetch SMILES
    smiles_list = [smiles_cache.get(ion.strip()) for ion in ions if smiles_cache.get(ion.strip()) is not None]
    return '.'.join(smiles_list)

# Specify the columns to process (e.g., ETL, HTL, etc.)
other_psc_layers = ['Substrate_stack_sequence', 'Backcontact_stack_sequence'] # 'ETL_stack_sequence', 'HTL_stack_sequence']

# Collect all unique ions from the dataset
all_ions = []
for col in other_psc_layers:
    df[col].dropna().apply(lambda x: all_ions.extend(x.replace('|', ':').split(':')))  # Normalize and split

# Remove duplicates
unique_ions = list(set(all_ions))

# Fetch SMILES for all unique ions and populate the cache
batch_fetch_smiles(unique_ions)

# Apply the conversion to each column
for col in other_psc_layers:
    df[col + '_SMILES'] = df[col].apply(convert_to_smiles)

# Save the updated DataFrame to a CSV file
output_file_path = 'cleaned_data_with_smiles.csv'
df.to_csv(output_file_path, index=False)

# Save the smiles_cache to a file for future use
with open(cache_file, 'w') as f:
    json.dump(smiles_cache, f)

print(f"Saved the cleaned data with SMILES to {output_file_path}.")
# Out:
# C:\Users\c\AppData\Local\Temp\ipykernel_22636\994698059.py:11: DtypeWarning: Columns (15,16,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'cleaned_data_with_smiles.csv')
# Loaded smiles cache from file.
# Error fetching SMILES for ion 'PDMS ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion ' CuNW ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'Nanopaper ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion ' Ag-mesh': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'PSSl ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'SnO2-c ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion ' TiO2': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion ' IZO ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion ' Ag-mesh': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...Error fetching SMILES for ion 'PDMS ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion ' CuNW ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'Nanopaper ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
#
# Error fetching SMILES for ion 'PSSl ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'SnO2-c ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion ' TiO2': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion ' IZO ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'Nanopaper ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...Error fetching SMILES for ion ' CuNW ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'PDMS ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion ' Ag-mesh': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'PSSl ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
#
# Error fetching SMILES for ion 'SnO2-c ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion ' TiO2': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion ' IZO ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion ' CuNW ': <urlopen error [Errno 11001] getaddrinfo failed>. Skipping.Error fetching SMILES for ion ' Ag-mesh': <urlopen error [Errno 11001] getaddrinfo failed>. Skipping.
# Error fetching SMILES for ion 'PDMS ': <urlopen error [Errno 11001] getaddrinfo failed>. Skipping.
# Error fetching SMILES for ion ' resist ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
#
# Error fetching SMILES for ion 'PSSl ': <urlopen error [Errno 11001] getaddrinfo failed>. Skipping.
# Error fetching SMILES for ion 'Nanopaper ': <urlopen error [Errno 11001] getaddrinfo failed>. Skipping.
# Error fetching SMILES for ion 'Flexible ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'Graphene': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'FPA-PDMS': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'Carbon-nt; PCBM-60': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'SnO2-c ': <urlopen error [Errno 11001] getaddrinfo failed>. Skipping.
# Error fetching SMILES for ion 'Carbon': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion ' TiO2': <urlopen error [Errno 11001] getaddrinfo failed>. Skipping.
# Error fetching SMILES for ion 'Silk ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion ' IZO ': <urlopen error [Errno 11001] getaddrinfo failed>. Skipping.
# Error fetching SMILES for ion ' ITO-HMDS Scaffold': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'Graphene': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...Error fetching SMILES for ion ' resist ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'Flexible ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'Carbon': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
#
# Error fetching SMILES for ion 'FPA-PDMS': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'Carbon-nt; PCBM-60': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'Silk ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion ' ITO-HMDS Scaffold': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion ' resist ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'Carbon': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'Graphene': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'FPA-PDMS': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'Carbon-nt; PCBM-60': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'Silk ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'Flexible ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion ' ITO-HMDS Scaffold': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'Carbon': <urlopen error [Errno 11001] getaddrinfo failed>. Skipping.Error fetching SMILES for ion ' resist ': <urlopen error [Errno 11001] getaddrinfo failed>. Skipping.
# Error fetching SMILES for ion ' Ti': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
#
# Error fetching SMILES for ion 'PET ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'Flexible ': <urlopen error [Errno 11001] getaddrinfo failed>. Skipping.
# Error fetching SMILES for ion 'Silk ': <urlopen error [Errno 11001] getaddrinfo failed>. Skipping.
# Error fetching SMILES for ion 'GaIn': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'b-CNF ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'Graphene': <urlopen error [Errno 11001] getaddrinfo failed>. Skipping.
# Error fetching SMILES for ion ' Cd2SnO4': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'Carbon-nt; PCBM-60': <urlopen error [Errno 11001] getaddrinfo failed>. Skipping.
# Error fetching SMILES for ion 'FPA-PDMS': <urlopen error [Errno 11001] getaddrinfo failed>. Skipping.
# Error fetching SMILES for ion 'Au ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion ' ITO-HMDS Scaffold': <urlopen error [Errno 11001] getaddrinfo failed>. Skipping.
# Error fetching SMILES for ion ' Graphite': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'PES ': <urlopen error [Errno 11001] getaddrinfo failed>. Retrying...
# Error fetching SMILES for ion 'Ca ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'PS': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'PEI (CAS # 61128-46-9) ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'AZO': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' AuCl3; Graphene': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Quartz ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' TCO': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Pt': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' AuAg ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'PSS ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'CSCNT@SnO2': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' Graphene ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' NiO ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Ti ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Ti-sheet': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Ni ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' ZrO2 ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' Pt ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Sb': 'PUGREST.ServerBusy'. Retrying...Error fetching SMILES for ion '1': 'PUGREST.ServerBusy'. Retrying...
#
# Error fetching SMILES for ion ' AlNi-grid': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'MWCNTs': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'In': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' SiN ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'PET': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Willow glass ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' PET': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'SiO2-mp ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Ti-grid': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'PSA': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' NiAl': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' APTES ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'SLG': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' Au-np; Graphene': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' SWCNTs': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'H': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'FTO ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'MoO2 ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Al': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'NOA88 ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'NOA88 ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' Organosilicate': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' Ni': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'PETUG': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'ATO': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'ATO': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'H2PtCl6': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Carbon ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Ni': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Ti-wire': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Unknown': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Bi2Te3': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' ZnS ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' TiO2-c ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'TFSA-Graphene ': 'PUGREST.ServerBusy'. Retrying...Error fetching SMILES for ion 'MoOx ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' Ag-nw; Graphene oxide': 'PUGREST.ServerBusy'. Retrying...
#
# Error fetching SMILES for ion 'Pt-Carbon-nt': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' Carbon': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' Cu-tape': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' ITO': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' SWCNTs ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'none': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'AgZn ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' PMMA ': 'PUGREST.ServerBusy'. Retrying...Error fetching SMILES for ion 'Ag@Au-np': 'PUGREST.ServerBusy'. Retrying...
#
# Error fetching SMILES for ion ' WO3 ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Bi ': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion ' IZO': 'PUGREST.ServerBusy'. Retrying...
# Error fetching SMILES for ion 'Graphene ': 'PUGREST.ServerBusy'. Retrying...
# Saved the cleaned data with SMILES to cleaned_data_with_smiles.csv.

# %%
import pandas as pd
import pubchempy as pcp
import json
import time
import random
from concurrent.futures import ThreadPoolExecutor

# Initialize an empty cache dictionary or load from a cache file
smiles_cache = {}
cache_file = 'smiles_cache.json'

# Load the cache from a file if it exists
try:
    with open(cache_file, 'r') as f:
        smiles_cache = json.load(f)
        print("Loaded SMILES cache from file.")
except FileNotFoundError:
    print("Cache file not found. Starting with an empty cache.")

# Function to fetch SMILES from PubChem with retries and exponential backoff
def fetch_smiles_from_pubchem(ion, retries=5, delay=2):
    """
    Fetch SMILES for a given ion from PubChem, with retries and exponential backoff.
    """
    for attempt in range(retries):
        try:
            compound = pcp.get_compounds(ion, 'name')
            if compound and compound[0].isomeric_smiles:
                return compound[0].isomeric_smiles
            else:
                return None  # No SMILES found
        except Exception as e:
            if attempt < retries - 1:  # Retry if attempts remain
                wait_time = delay * (2 ** attempt) + random.uniform(0, 1)  # Add jitter
                print(f"Error fetching SMILES for ion '{ion}': {e}. Retrying in {wait_time:.2f} seconds...")
                time.sleep(wait_time)
            else:
                print(f"Error fetching SMILES for ion '{ion}': {e}. No more retries.")
                return None

# Function to fetch SMILES in batch
def fetch_smiles_batch(ions, retries=5):
    """
    Fetch SMILES for a batch of ions.
    """
    results = {}
    for ion in ions:
        if ion not in smiles_cache:
            smiles = fetch_smiles_from_pubchem(ion, retries=retries)
            if smiles:
                results[ion] = smiles
    return results

# Batch processing with limited concurrency
def batch_fetch_smiles(ions, batch_size=10):
    """
    Fetch SMILES for ions in batches, limiting the number of requests.
    """
    for i in range(0, len(ions), batch_size):
        batch = ions[i:i + batch_size]
        batch_results = fetch_smiles_batch(batch)
        smiles_cache.update(batch_results)

# Function to convert Ion column to SMILES using the cache
def convert_to_smiles(ion_str):
    """
    Converts a string of ions into their SMILES representation.
    Handles multiple ions separated by ':' or '|'.
    """
    if pd.isna(ion_str):  # Handle missing values
        return None
    
    # Normalize delimiters to ':' and split the ions
    normalized_str = ion_str.replace('|', ':')
    ions = normalized_str.split(':')
    
    # Use the cache to fetch SMILES
    smiles_list = [smiles_cache.get(ion.strip()) for ion in ions if smiles_cache.get(ion.strip()) is not None]
    return '.'.join(smiles_list)

# Specify the columns to process
other_psc_layers = ['Substrate_stack_sequence', 'ETL_stack_sequence', 'HTL_stack_sequence', 'Backcontact_stack_sequence']  # Update column names if needed

# Example DataFrame for demonstration (replace this with your actual DataFrame)
# Ensure the column names in your DataFrame match `other_psc_layers`
df = pd.read_csv(r'cleaned_data_with_smiles.csv')

# Collect all unique ions from the dataset
all_ions = []
for col in other_psc_layers:
    if col in df.columns:  # Check if the column exists in the DataFrame
        df[col].dropna().apply(lambda x: all_ions.extend(x.replace('|', ':').split(':')))  # Normalize and split

# Remove duplicates
unique_ions = list(set(all_ions))

# Fetch SMILES for all unique ions in batches
batch_fetch_smiles(unique_ions)

# Apply the conversion to each column
for col in other_psc_layers:
    if col in df.columns:  # Check if the column exists
        df[col + '_SMILES'] = df[col].apply(convert_to_smiles)

# Save the updated DataFrame to a CSV file
output_file_path = 'cleaned_data_with_smiles.csv'
df.to_csv(output_file_path, index=False)

# Save the smiles_cache to a file for future use
with open(cache_file, 'w') as f:
    json.dump(smiles_cache, f)

print(f"Saved the cleaned data with SMILES to {output_file_path}.")
# Out:
# Loaded SMILES cache from file.
# C:\Users\c\AppData\Local\Temp\ipykernel_23040\1912187710.py:86: DtypeWarning: Columns (15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'cleaned_data_with_smiles.csv')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 98
#      95 unique_ions = list(set(all_ions))
#      97 # Fetch SMILES for all unique ions in batches
# ---> 98 batch_fetch_smiles(unique_ions)
#     100 # Apply the conversion to each column
#     101 for col in other_psc_layers:
#
# Cell In[5], line 61, in batch_fetch_smiles(ions, batch_size)
#      59 for i in range(0, len(ions), batch_size):
#      60     batch = ions[i:i + batch_size]
# ---> 61     batch_results = fetch_smiles_batch(batch)
#      62     smiles_cache.update(batch_results)
#
# Cell In[5], line 49, in fetch_smiles_batch(ions, retries)
#      47 for ion in ions:
#      48     if ion not in smiles_cache:
# ---> 49         smiles = fetch_smiles_from_pubchem(ion, retries=retries)
#      50         if smiles:
#      51             results[ion] = smiles
#
# Cell In[5], line 27, in fetch_smiles_from_pubchem(ion, retries, delay)
#      25 for attempt in range(retries):
#      26     try:
# ---> 27         compound = pcp.get_compounds(ion, 'name')
#      28         if compound and compound[0].isomeric_smiles:
#      29             return compound[0].isomeric_smiles
#
# File c:\Users\c\miniconda3\envs\test-env\Lib\site-packages\pubchempy.py:321, in get_compounds(identifier, namespace, searchtype, as_dataframe, **kwargs)
#     312 def get_compounds(identifier, namespace='cid', searchtype=None, as_dataframe=False, **kwargs):
#     313     """Retrieve the specified compound records from PubChem.
#     314
#     315     :param identifier: The compound identifier to use as a search query.
#    (...)
#     319                          :class:`~pandas.DataFrame` and return that.
#     320     """
# --> 321     results = get_json(identifier, namespace, searchtype=searchtype, **kwargs)
#     322     compounds = [Compound(r) for r in results['PC_Compounds']] if results else []
#     323     if as_dataframe:
#
# File c:\Users\c\miniconda3\envs\test-env\Lib\site-packages\pubchempy.py:299, in get_json(identifier, namespace, domain, operation, searchtype, **kwargs)
#     297 """Request wrapper that automatically parses JSON response and supresses NotFoundError."""
#     298 try:
# --> 299     return json.loads(get(identifier, namespace, domain, operation, 'JSON', searchtype, **kwargs).decode())
#     300 except NotFoundError as e:
#     301     log.info(e)
#
# File c:\Users\c\miniconda3\envs\test-env\Lib\site-packages\pubchempy.py:292, in get(identifier, namespace, domain, operation, output, searchtype, **kwargs)
#     290             response = request(identifier, namespace, domain, operation, output, searchtype, **kwargs).read()
#     291 else:
# --> 292     response = request(identifier, namespace, domain, operation, output, searchtype, **kwargs).read()
#     293 return response
#
# File c:\Users\c\miniconda3\envs\test-env\Lib\site-packages\pubchempy.py:271, in request(identifier, namespace, domain, operation, output, searchtype, **kwargs)
#     269     log.debug('Request URL: %s', apiurl)
#     270     log.debug('Request data: %s', postdata)
# --> 271     response = urlopen(apiurl, postdata)
#     272     return response
#     273 except HTTPError as e:
#
# File c:\Users\c\miniconda3\envs\test-env\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File c:\Users\c\miniconda3\envs\test-env\Lib\urllib\request.py:515, in OpenerDirector.open(self, fullurl, data, timeout)
#     512     req = meth(req)
#     514 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 515 response = self._open(req, data)
#     517 # post-process response
#     518 meth_name = protocol+"_response"
#
# File c:\Users\c\miniconda3\envs\test-env\Lib\urllib\request.py:532, in OpenerDirector._open(self, req, data)
#     529     return result
#     531 protocol = req.type
# --> 532 result = self._call_chain(self.handle_open, protocol, protocol +
#     533                           '_open', req)
#     534 if result:
#     535     return result
#
# File c:\Users\c\miniconda3\envs\test-env\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File c:\Users\c\miniconda3\envs\test-env\Lib\urllib\request.py:1392, in HTTPSHandler.https_open(self, req)
#    1391 def https_open(self, req):
# -> 1392     return self.do_open(http.client.HTTPSConnection, req,
#    1393                         context=self._context)
#
# File c:\Users\c\miniconda3\envs\test-env\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1346     except OSError as err: # timeout error
#    1347         raise URLError(err)
# -> 1348     r = h.getresponse()
#    1349 except:
#    1350     h.close()
#
# File c:\Users\c\miniconda3\envs\test-env\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File c:\Users\c\miniconda3\envs\test-env\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\c\miniconda3\envs\test-env\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\c\miniconda3\envs\test-env\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File c:\Users\c\miniconda3\envs\test-env\Lib\ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\c\miniconda3\envs\test-env\Lib\ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Generating vector embeddings from SMILES strings

# %%
import pandas as pd
from transformers import AutoTokenizer, AutoModel
import torch

# Load ChemBERTa model and tokenizer from Hugging Face
model_name = "seyonec/ChemBERTa-zinc-base-v1"  # Change model if needed
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# Function to combine individual SMILES in a column into a single string
def combine_column_smiles(smiles_str):
    if pd.isna(smiles_str):  # Handle missing values
        return None
    # Split by '.' if there are multiple SMILES in the same cell
    smiles_list = smiles_str.split('.')
    # Combine the SMILES in the cell (you can join them by '.' or other delimiters)
    return '.'.join([smiles for smiles in smiles_list if smiles.strip()])

def combine_row_smiles(row):
    # Access the SMILES for each composition by column name
    combined_smiles_1 = combine_column_smiles(row['Perovskite_composition_a_ions_SMILES'])
    combined_smiles_2 = combine_column_smiles(row['Perovskite_composition_b_ions_SMILES'])
    combined_smiles_3 = combine_column_smiles(row['Perovskite_composition_c_ions_SMILES'])
    
    # Combine the SMILES from all columns into one single SMILES string
    return '.'.join(filter(None, [combined_smiles_1, combined_smiles_2, combined_smiles_3]))

# Assuming your DataFrame has the proper column names
df['Combined_SMILES'] = df.apply(combine_row_smiles, axis=1)

# Check the resulting DataFrame
print(df[['Combined_SMILES']])

# # Function to convert a SMILES string to a vector embedding
# def smiles_to_embedding(smiles, model, tokenizer):
#     # Tokenize the SMILES string
#     inputs = tokenizer(smiles, return_tensors="pt", padding=True, truncation=True)
    
#     # Pass the tokens through the model
#     with torch.no_grad():
#         outputs = model(**inputs)
    
#     # Get the embeddings (last hidden state)
#     embeddings = outputs.last_hidden_state
    
#     # You can either use the embedding of the [CLS] token or average all token embeddings
#     cls_embedding = embeddings[:, 0, :]  # [CLS] token embedding
#     avg_embedding = embeddings.mean(dim=1)  # Average embedding of all tokens
    
#     return cls_embedding, avg_embedding

# # Generate embeddings for the combined SMILES strings
# embeddings_cls = []
# embeddings_avg = []

# for smiles in df['Combined_SMILES']:
#     cls_embedding, avg_embedding = smiles_to_embedding(smiles, model, tokenizer)
#     embeddings_cls.append(cls_embedding)
#     embeddings_avg.append(avg_embedding)

# # Convert embeddings into numpy arrays for easier manipulation
# embeddings_cls = torch.cat(embeddings_cls, dim=0).numpy()
# embeddings_avg = torch.cat(embeddings_avg, dim=0).numpy()

# print("CLS Embeddings:", embeddings_cls)
# print("Average Embeddings:", embeddings_avg)

# # Optional: You can store the embeddings back in the DataFrame if you want to keep them for future use
# df['Embedding_CLS'] = embeddings_cls.tolist()
# df['Embedding_Avg'] = embeddings_avg.tolist()

# # Save to a new CSV file (optional)
# df.to_csv('materials_with_embeddings.csv', index=False)
# Out:
#       Combined_SMILES
# 0
# 1
# 2
# 3
# 4
# ...               ...
# 39965
# 39966
# 39967
# 39968
# 39969
#
# [39970 rows x 1 columns]
